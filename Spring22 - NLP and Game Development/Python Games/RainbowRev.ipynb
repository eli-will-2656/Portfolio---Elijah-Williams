# %%
from typing import Counter
import math
import random
import sys,time
COLORS = []

#Violet Section Fixed
#In the definition of blue_color(), changed "blue" to "BLUE," so as to be consistent with the function COLORS[].
#################### START OF YELLOW DESERT SECTION ##########################
def desert(cnt):
  canteen = False;
  map = False;
  stick = False;
  antiVenom = False;
  alive = True
  location = 0;
  # Starting Conditions

  prompt = """\nYou appear in a desert and all you can see is sand. You have never been 
this thirsty in your life. You see a sign that says "Find a yellow canteen in order to survive"."""
  choices = ["1.) Go North", "2.) Go West", "3.) Go East", "4.) Leave desert"]
  print(prompt)
  writeArray(choices)
  response = int(input("What will you do? (Enter a number) "))
  while(response < 1 or response > len(choices)) :
    response = input('Try again, incorrect input (Enter a number): ')
  cnt = cnt - 1
  if response == 1 : location = 9
  elif response == 2: location = 2
  elif response == 3: location = 1
  elif response == 4: location = -1

  while cnt > 0 and location != -1:
    # Set prompt and choice based on location and items 
    special = False
    if location == 0:
      prompt = "Hey, isn't this where your started?"
      choices = ["1.) Go North", "2.) Go West", "3.) Go East", "4.) Leave Desert"]      
    elif location == 1:
      prompt = "I dont see a canteen.\nJust Sand... Sand... and more Sand."
      choices = ["1.) Go West", "2.) Go East", "3.) Go South", "4.) Leave Desert"]
    elif location == 2:
      prompt = 'Don\'t you love the feel of the sun on your back?\nNo... Then keep looking for that canteen'
      choices = ["1.) Go West", "2.) Go East", "3.) Go South", "4.) Leave Desert"]
    elif location == 3:
      prompt = "Wow this desert is big"
      choices = ["1.) Go North", "2.) Go East", "3.) Leave Desert"]
    elif location == 4:
      prompt = "You should just keep walking"
      choices = ["1.) Go South", "2.) Go East", "3.) Leave Desert"]
    elif location == 5:
      prompt = "No yellow canteen in sight"
      choices = ["1.) Go South", "2.) Go West", "3.) Leave Desert"]
    elif location == 6:
      if antiVenom == False:
        prompt = "You find a backpack with a strange bottle inside."
        choices = ["1.) Grab the backpack", "2.) Go North", "3.) Go West", "4.) Leave Desert"]
      else :
        special = True;
        prompt = "Lets keep walking."
        choices = ["1.) Go North", "2.) Go West", "3.) Leave Desert"]

    elif location == 7:
      if map == False:
        prompt = "You find a strange map on the ground."
        choices = ["1.) Pick Up the Map", "2.) Go North", "3.) Go West", "4.) Leave Desert"]
      else :
        special = True;
        prompt = "Lets keep walking."
        choices = ["1.) Go North", "2.) Go West", "3.) Leave Desert"]
    elif location == 8:
      if stick == False:
        prompt = "You find a stick on the ground.\nDoesn't seem all that interesting but its a stick"
        choices = ["1.) Pick Up the Stick", "2.) Go North", "3.) Go East", "4.) Leave Desert"]
      else :
        special = True;
        prompt = "Lets keep walking."
        choices = ["1.) Go North", "2.) Go East", "3.) Leave Desert"]
    elif location == 9:
      if map == False:
        prompt = "This part of the desert is really confusing. You can't tell which way is which"
        choices = ["1.) Go ahead", "2.) Leave Desert"]
      else :
        special = True;
        prompt = "Lets look at the map of ours. Ah Okay! I see something ahead"
        choices = ["1.) Go North", "2.) Go South", "3.) Go East", "4.) Go West", "5.) Leave Desert"]
    elif location == 10:
      if stick == False:
        prompt = "Eak theres a snake!"
        choices = ["1.) Fight the snake with your hands", "2.) Run away", "3.) Leave Desert"]
      else :
        special = True;
        prompt = "Eak theres a snake"
        choices = ["1.) Fight the snake with your stick", "2.) Run Away", "3.) Leave Desert"]
    elif location == 11:
      prompt = "You find the yellow canteen"
      choices = ["1.) Pick up the yellow canteen and Leave desert"]    
    
    # print prompt and choices
    print("\n" + prompt)
    writeArray(choices)

    # ask for user choice make sure its valid
    response = int(input("What will you do? (Enter a number) "))
    while(response < 1 or response > len(choices)) :
      response = input('Try again, incorrect input (Enter a number): ')

    # decrement count
    cnt = cnt - 1
    
    # exectute user choice and make updates 
    if location == 0:
      if response == 1:
        location = 9
      if response == 2:
        location = 2
      if response == 3:
        location = 1
      if response == 4:
        location = -1

    elif location == 1:
      if response == 1:
        location = 0
      if response == 2:
        location = 7
      if response == 3:
        location = 6
      if response == 4:
        location = -1

    elif location == 2:
      if response == 1:
        location = 8
      if response == 2:
        location = 0
      if response == 3:
        location = 3
      if response == 4:
        location = -1

    elif location == 3:
      if response == 1:
        location = 2
      if response == 2:
        location = 6
      if response == 3:
        location = -1
   
    elif location == 4:
      if response == 1:
        location = 8
      if response == 2:
        location = 9
      if response == 3:
        location = -1

    elif location == 5:
      if response == 1:
        location = 7
      if response == 2:
        location = 9
      if response == 3:
        location = -1

    elif location == 6:
      if special:
        if response == 1:
          location = 1
        if response == 2:
          location = 3
        if response == 3:
          location = -1
      else: 
        if response == 1:
          antiVenom = True;
        if response == 2:
          location = 1
        if response == 3:
          location = 3
        if response == 4:
          location = -1

    elif location == 7:
      if special:
        if response == 1:
          location = 5
        if response == 2:
          location = 1
        if response == 3:
          location = -1
      else: 
        if response == 1:
          map = True;
        if response == 2:
          location = 5
        if response == 3:
          location = 1
        if response == 4:
          location = -1

    elif location == 8:
      if special:
        if response == 1:
          location = 4
        if response == 2:
          location = 2
        if response == 3:
          location = -1
      else: 
        if response == 1:
          stick = True;
        if response == 2:
          location = 4
        if response == 3:
          location = 2
        if response == 4:
          location = -1

    elif location == 9:
      if special:
        if response == 1:
          location = 10
        if response == 2:
          location = 0
        if response == 3:
          location = 5
        if response == 4:
          location = 4
        if location == 5:
          location = -1
      else: 
        if response == 1:
          location = 0;
        if response == 2:
          location = -1;

    elif location == 10:
      if special:
        if response == 1:
          print("\nYou got passed the snake!")
          location = 11
        if response == 2:
          location = 9
        if response == 3:
          location = -1;
      else:
        if response == 1:
          if antiVenom:
            print("\nThe snake bit you! But luckily you had a bottle of antivenom\nYou get away")
            location = 0
          else: 
            print("\nThe snake bit you!")
            return 0
        if response == 2:
          location = 9
        if response == 3:
          location = -1
    elif location == 11:
      canteen = True;
      location = -1
  return cnt, canteen;

 # Helper
def writeArray(arr) :
  print("Your choices are:")
  for str in arr:
    print(str)
##################END OF YELLOW DESERT SECTION ################################


#################   Start of Violet Section #####################
#### Cite the function "violet_forum()" if you want to start the section
#Parameters
violet_first_time_forum = 1
violet_first_time_statue = 1
violet_first_time_temple = 1
violet_first_time_bibliotheca = 1
violet_first_time_senate = 1
violet_empire = 0
violet_pallium = 0
violet_die = 0
violet_wood_case = 0 
violet_toga = 0
violet_found_dinari = 0
violet_pick_up_dinari = 0
violet_dinari = 0
violet_senate_knock = 0
violet_senate_doorman = 1
violet_papyrus = 0
#Functions
###Opening Scene / Scene Forum
def violet_forum_description(counter):
  global violet_first_time_forum
  global violet_senate_knock
  if violet_first_time_forum == 1:
    print('''
      You found yourself in a Roman forum, its ground paved with rectangular blocks of stones. 

      [Ahead] of you was an imposing [Statue] of marble. It seemed like a general solemnly looking afar, his hand raised and pointing forward. A purple pallium wrapped up his cuirass, and under his bare feet was a cubic base, also made of marble, with some inscriptions on it.

      On the [Right] was a [Temple] of large-cut white stones, and behind the Corinthian columns was a dark inlet, leading to the altar.

      On the [Left] was another [House] of concrete raised above the ground. Standing upon it was an iron effigy of a winged goddess, and the steps in front of it led toward a heavy bronze door.

      And, [Behind] you was a [Bibliotheca], of two stories, fairly vented.

      \x1B[3m
      When in Rome, Do as the Romans:
      To Navigate Around, Use [Go], [Pick up], [Talk to] or Other Actions Specific to the Senario, as Highlighted by []
      If You Get Lost, Find [Direction]
      If You Need Help, Ask for [Help]
      If You Wanna Give Up, [Exit]
      \x1B[0m
      ''')
  else:
      if violet_senate_knock == 0:
        print('''
        You were in the forum again.
        [Ahead] of you was the [Statue].
        On the [Right] was the [Temple].
        On the [Left] was the [House].
        [Behind] you was the [Bibliotheca].
        To Navigate Around, Use [Go], [Pick up] and [Talk to]
        If You Need Help, Get [Direction]
        If You Wanna Give Up, [Exit]
        ''')
      else:
        print('''
        You were in the forum again.
        [Ahead] of you was the [Statue].
        On the [Right] was the [Temple].
        On the [Left] was the [Senate].
        [Behind] you was the [Bibliotheca].
        ''')

def violet_help():
  print('''
  \x1B[3m
      When in Rome, Do as the Romans:
      To Navigate Around, Use [Go], [Pick up], [Talk to] or Other Actions Specific to the Senario, as Highlighted by []
      If You Get Lost, Find [Direction]
      If You Need Help, Ask for [Help]
      If You Wanna Give Up, Go Find [Exit] at the [Forum]
      \x1B[0m
  ''')

def violet_forum_direction(counter):
  global violet_senate_knock
  while True:
      print("What would you do?")
      answer = input()
      if answer == "Go to Statue" or answer == "go Statue" or answer == "Go Ahead" or answer == "go Ahead":
        violet_statue(counter)
        break
      elif answer == "Go Right" or answer == "go Right" or answer == "go Temple" or answer == "Go Temple":
        violet_temple(counter)
        break
      elif answer == "Go Left" or answer == "go Left" or answer == "Go House" or answer == "go House":
        violet_senate(counter)
        break
      elif answer == "Go Left" or answer == "go Left" or answer == "Go House" or answer == "go House" or answer == "Go Senate" or answer == "go Senate": 
        try:
          if violet_senate_knock == 1:
            violet_senate(counter)
            break
        except:
          print("True that it seemed like Rome...but what Senate?")
          continue
      elif answer == "Go Behind" or answer == "go Behind" or answer == "Go Bibliotheca" or answer == "go Bibliotheca":
        violet_bibliotheca(counter)
        break
      elif answer == "description" or answer == "description":
        violet_forum_description(counter)
        continue
      elif answer == "Help" or answer == "help":
        violet_help()
        continue
      elif answer == "Exit" or "exit":
        main()
        break
      else:
        print("Pardon?")
        continue

def violet_forum(counter):
  global violet_first_time_forum
  if violet_papyrus == 0:
    if violet_first_time_forum == 1:
      violet_forum_description(counter)
      violet_first_time_forum = 0
    else: print("You are at the forum.")
    violet_forum_direction(counter)
  if violet_papyrus == 1:
    print("Never More")
    return counter
    main()

##Branches
###Scene Statue
def violet_statue_description(counter):
  global violet_empire
  global violet_pallium
  if (violet_empire == 0 and violet_pallium == 0) == True:
    print('''
    From the [Forum] [Behind], you came under the feet of the Statue of the general.

    A purple [Pallium] wrapped up his cuirass, and under his bare feet was a cubic base, also made of marble, with some [Inscriptions] on it.

    You had come close enough to the Statue so you could try to [Read Inscriptions].

    The Statue's base was not so high, and you might climb up it and strip the dead man of his vanity.
    
    (Or, [leave Caesar’s to Caesar?])
    ''')
  else:
    print('''
    From the [Forum] [Behind], you came under the feet of the [Statue] of the general.

    The [Statue] was still there, but the glory of the past was no more. 
    ''')

def violet_statue_empire(counter):
  global violet_empire
  global violet_die
  while True:
    print('\x1B[3m Is not it heroic to acquire an empire?  \x1B[0m [Y/N]')
    answer = input()
    if answer == "Y" or answer == "Yes" or answer == "yes":
      print("\x1B[3m So you may also try your fortune. \x1B[0m")
      print("You found at the base of the statue a [Die].")
      print("What would you do?")
      answer_die = input()
      ##Better to have a loop within loop, but I do not know how to realize it.
      try:
        if answer_die == "Pick up Die" or answer_die == "pick up Die" or answer_die == "Pick Up Die":
          ##Change the codes here if you want to add the [Die] to the Objects.
          violet_die = 1
          print("Then you have the [Die].")
          print("And you looked up and saw the Pallium breaking into dusts.")
          violet_empire = 1
          break
      except:
        print("The [DIE] was cast and rolled away. [You did not have the [DIE].")
        continue
    elif answer == "N" or answer == "No" or answer == "no":
      print("\x1B[ fere libenter homines id quod volunt credun \x1B[0m")
      break
    else:
      print("Pardon?")
      continue

def violet_statue_pallium(counter):
  global violet_pallium
  print('''
  You climbed up the base and lay your hand upon the pallium. Once you touched it, however, its color faded, and the clothe broke up into dusts.
  \x1B[3m
  O wealth and empire and skill by skill
  Outwitted in the battlefield of life,
  What spite and envy follow in your train!
  \x1B[0m
  Though the heart of man could never satisfy itself, things acquired by force must be yielded to force, and the glory and honor gone with it.
  ''')
  violet_pallium = 1

def violet_statue_direction(counter):
  global violet_pallium
  global violet_empire
  while True:
    print("What would you do?")
    answer = input()
    if answer == "Pick up Pallium" or answer == "pick up Pallium":
      if violet_pallium == 0 and violet_empire == 0:
        violet_statue_pallium(counter)
        continue
      else: 
        print("The ashes were gone already.")
        continue
    elif answer == "Read Inscriptions" or answer == "read Inscriptions" or answer == "leave Caesar’s to Caesar":
        print("The inscriptions were blurred, but the heading was larger, so you were able to identify them. It read: PLVS VLTRA.")
        if violet_empire == 0 and violet_pallium == 0:
          violet_statue_empire(counter)
          continue
        else: 
          print('''And nothing happened
          \x1B[3m
          Since you have cast the die already
          \x1B[0m
          ''')
          continue
    elif answer == "Go Forum" or answer == "go Forum" or answer == "Go Behind" or answer == "go Behind":
      violet_forum(counter)
      break
    elif answer == "Description" or answer == "description":
      violet_statue_description(counter)
      continue
    elif answer == "Help" or answer == "help":
      violet_help()
      continue
    else:
      print("Pardon?")
      continue

def violet_statue(counter):
  global violet_first_time_statue
  if violet_first_time_statue == 1:
    violet_first_time_statue = 0
    violet_statue_description(counter)
  else:
    print("You came under the Statue.")
  violet_statue_direction(counter)


###Scene Temple
def violet_temple_description(counter):
  if violet_wood_case == 0 and violet_toga == 0:
    print('''
    You entered the temple from the [Forum] [Ahead] of it.
    
    By the flickering fire of the altar, you saw the effigy of a god whose complexion, strained by the light and shadow, looked unbecoming. 

    Upon its lap was a [Wood Case], of very fine texture.

    Besides, you vaguely perceived that there were other things in the dark but could not tell clearly. Nevertheless, you might [Look around] and try to find them.

    ''')
  elif violet_wood_case == 1 and violet_toga == 0:
    print('''
    You entered the temple.

    The deity of the past was no more observed,

    the altar covered by remnants, and the room unlit.
    
    But, amidst this deadness, you might still find some smoldering ashes
    
    pretending the light of the past. [Look around]
    ''')
  else:
    print('''
    You entered the temple.

    No light, nothing stirs, all ruins.

    \x1B[3m Never more  \x1B[0m
    ''')

def violet_temple_direction(counter):
  global violet_wood_case
  global violet_toga
  while True:
    print("What would you do?")
    answer = input()
    if answer == "Pick up Wood Case" or answer == "pick up Wood Case":
      if violet_wood_case == 0:
        print('''
        You had the wood case and opened it. However, nothing was in it.
        \x1B[3m 
        No more were sacrifices made to the gods of the ancient.
        \x1B[0m
        ''')
        violet_wood_case = 1
        continue
      else:
        print("What wood case?")
        continue
    elif answer == "Look around" or answer == "look around" or answer == "Look Around":
      if violet_toga == 0:
        print('''
        As you walked around, you stubbled into something on the floor. You dragged the thing into light, and it turned out to be a fine chest.

        You opened the chest and found in it the priest’s [Toga].

        What would you do with it?
        ''')
        answer_toga = input()
        if answer_toga == "Pick up Toga" or answer_toga == "Pick Up Toga" or answer_toga == "pick up Toga":
            print('''Then you have the toga.
            \x1B[3m As should any Roman Senator. \x1B[0m
            ''')
            violet_toga = 1
            continue
        else:
          print('''And you left the [Toga] in the chest.
          \x1B[3m But you might still [Pick up] the toga, when needed. \x1B[0m
          ''')
          continue
      else:
        print("There was nothing so you found nothing.")
        continue
    elif answer == "Go Forum" or answer == "go Forum" or answer == "Go Ahead" or answer == "go Ahead":
        violet_forum(counter)
        break
    elif answer == "Description" or answer == "description":
        violet_temple_description(counter)
        continue
    elif answer == "Help" or answer == "help":
        violet_help()
        continue
    else:
        print("Pardon?")
        continue

def violet_temple(counter):
  global violet_first_time_temple
  if violet_first_time_temple == 1:
    violet_first_time_temple = 0
    violet_temple_description(counter)
  else:
    print("You entered the [Temple].")
  violet_temple_direction(counter)


##Scene Bibliotheca
def violet_bibliotheca_description(counter):
  global violet_pick_up_dinari
  if violet_pick_up_dinari == 0:
    print('''
    You entered the [Bibliotheca].

    Once filled with the trophies of conquest, the bibliotheca now had nothing in it but ashes.

    \x1B[3m All we gather will be lost. \x1B[0m

    But, you might still find something in ash, if you [Dig ashes] hard enough
    ''')
  if violet_pick_up_dinari == 1:
    print('''
    You entered the [Bibliotheca].

    Once filled with the trophies of conquest, the bibliotheca now had nothing in it but ashes.

    \x1B[3m And ashes are ashes. Better to create than to dig in the ashes. \x1B[0m
    ''')

def violet_bibliotheca_direction(counter):
  global violet_found_dinari
  global violet_pick_up_dinari
  global violet_dinari
  while True:
    print("What would you do?")
    answer = input()
    if answer == "Dig ashes" or answer == "dig ashes":
      if violet_found_dinari == 0:
        print('''
        You dug the ashes hard, and you did find some [Dinari] in it, possibly lost by some readers in the past.
        \x1B[3m
        Knowledge is good, isn’t it?
        \x1B[0m
        ''')
        print("What to do with the [Dinari]? [Pick up Dinari] of course!")
        answer = input()
        if answer == "Pick up Dinari" or answer == "Pick Up Dinari" or answer == "Pick up dinari" or answer == "pick up dinari":
            print("Then you have the [Dinari]")
            violet_found_dinari = 1
            violet_dinari = 5
            continue
        else:
          print("It seemed that you did not want soil your hand, so you left the [Denari] there.")
          print("When necessity compells, you might return for them, but there was no guarantee that you would have as many, for the ashes were thick.")
          violet_found_dinari = 1
          continue
      else:
        if violet_pick_up_denari == 0:
          from random import randint
          violet_dinari = randint(1, 5)
          print('''
          You dug the ashes and did find the [Dinari], again.

          But, since you had rejected the favor of Fortune once,

          this time it would not be as much.
          ''')
          print("And you had" + str(violet_dinari)+"[Dinari]")
          print('''What to do with the [Dinari]?
          \x1B[3m
          Be good and [Pick up Dinari]!
          \x1B[0m
          ''')
          answer = input()
          if answer == "Pick up Dinari" or answer == "Pick Up Dinari" or answer == "Pick up dinari" or answer == "pick up dinari":
            print("Then you have the [Dinari]")
            violet_found_dinari = 1
            violet_dinari = 5
            continue
          else:
            print('''
            \x1B[3m
            Well, again...
            \x1B[0m
            So you still did not want the [Denari] and dropped them there.
            ''')
            continue
        else:
          print("You dugged the ashes futilely, coughed a lot, and found nothing.")
          continue
    elif answer == "Go Forum" or answer == "go Forum" or answer == "Go Ahead" or answer == "go Ahead":
        violet_forum(counter)
        break
    elif answer == "Description" or answer == "description":
        violet_bibliotheca_description(counter)
        continue
    elif answer == "Help" or answer == "help":
        violet_help()
        continue
    else:
        print("Pardon?")
        continue

def violet_bibliotheca(counter):
  global violet_first_time_bibliotheca
  if violet_first_time_bibliotheca == 1:
    violet_first_time_bibliotheca = 0
    violet_bibliotheca_description(counter)
  else:
    print("You entered the [Bibliotheca].")
  violet_bibliotheca_direction(counter)


###Scene House/Senate
def violet_senate_description(counter):
  if violet_senate_knock == 0:
    print('''
    You went up the steps of the [House] and found the bronze door shut.
    
    You would like to find a way in...

    So try "[Knock Knock]?"
    ''')
  else:
    if violet_senate_doorman == 1:
      print('''
      You went to the [Senate] again.

      Unfortunately, the [Doorman] was still there.

      You must devise a way to pass him, by [Pretense] or by [Conquest].
      ''')
    else:
      print('''
      You went to the [Senate] again.

      The doorman had gone.
      \x1B[3m
      Dépêche-toi ! We are almost done! What are you waiting for? [Go Senate]!
      \x1B[0m
      ''')

def violet_senate_direction(counter):
  global violet_senate_knock
  global violet_die
  global violet_dinari
  global violet_senate_doorman
  global violet_toga
  global violet_papyrus
  while True:
    "What would you do?"
    answer = input()
    if violet_senate_knock == 0:
      if answer == "Knock Knock":
        print('''
        "Who's there? Of course me the [Doorman]!
         I am always here, guarding the door of Senate
         \x1B[3m the way to the consummation, the way to the end \x1B[0m
         \x1B[3m Show me your credential or you are not allowed here yet! \x1B[0m "
         ''')
        print("You waited till the [Doorman] stopped his quibbling, to [Talk to] him again. Or, you might leave him for now.")
        violet_senate_knock = 1
        continue
      elif answer == "Go Forum" or answer == "go Forum" or answer == "Go Ahead" or answer == "go Ahead":
          violet_forum()
          break
      elif answer == "Help" or answer == "help":
        violet_help()
        continue
      else:
        print('''
        You did something, and it might work.
        \x1B[3m But, at this solemn and boring place, they have their unique password, and admit nothing else. \x1B[0m
        ''')
        continue
    else:
      if violet_senate_doorman == 1:
        if answer == "Talk to Doorman" or answer == "talk to Doorman" or answer == "Talk to doorman" or answer == "talk to doorman":
          print('''
          "I said, show me your credential, by [Pretense] or [Conquest]!"
          Choose a way. THEN, [Use] something to get rid of him.
          ''')
          answer = input()
          if answer == "Conquest":
            print("Use what?")
            answer = input()
            if answer == "Use Die" and violet_die == 1:
              if violet_dinari > 0:
                print('''
                The Die is cast.

                You gambled with the doorman...
                ''')
                from random import randint
                violet_die_you = randint(1, 6)
                violet_die_doorman = randint (1, 6)
                if violet_die_you > violet_die_doorman:
                  print("And you won! The Doorman refused to surrender his dinari and fled! You may now [Go] inside the [Senate].")
                  violet_senate_doorman = 0
                  continue
                elif violet_die_you == violet_die_doorman:
                    print('''Tie!
                    You may try again --- first, [Talk to Doorman] again and then still [Use Die] --- or try another way...''')
                    continue
                elif violet_die_you < violet_die_doorman:
                  violet_dinari = violet_dinari -1
                  print('''You lost! You had to surrender 1 d. to the Doorman.
                  You may try again --- first, [Talk to Doorman] again and then still [Use Die] --- or try another way ...''')
                  continue
              else:
                print("Unfortunately, you had lost all you dinari and could gamble no more. [Talk to Doorman] and Try something else maybe?")
                continue
            else:
              print("That does not make sense! Think again! [Talk to Doorman] and choose either [Pretense] or [Conquest?]")
              continue
          elif answer == "Pretense":
            print("Use what?")
            answer = input()
            if answer == "Use Toga" and violet_toga == 1:
              print('''You put on the Toga and looked like a senator.
              With the eloquence that this Toga conferred to you, as if by magic, you chastized the Doorman and ordered him to leave.
              You may now [Go] into the [Senate]''')
              violet_senate_doorman = 0
              continue
            else:
              print("That does not make sense! Think again![Pretense or Conquest?]")
              continue
          elif answer == "Go Forum" or answer == "go Forum" or answer == "Go Ahead" or answer == "go Ahead":
            violet_forum(counter)
            break
          elif answer == "Help" or answer == "help":
              violet_help()
              continue
          else:
            print("Pardon?")
            continue
      else:
          if answer == "Go Senate" or answer == "go Senate" or answer == "go senate" or answer == "Go senate":
            print('''
            You entered the [Senate].

            The proceedings of the day seemed to have ended, and none was there.

            You found at the center of the room some [Papyrus]. You read the words on it, and it seemed something judicial.

            When you went through all the pieces and turned to the last piece, you found its back dyed violet.

            You may [Pick up Papyrus].

            ''')
            print("What to do with the [Papyrus]?")
            answer = input()
            if answer == "Pick up Papyrus":
              print('''
              \x1B[3m
              Rome had conquered the world three times: the first through its armies, the second through its religion, the third through its laws, each time more thoroughly.
              \x1B[0m
              ''')
              violet_papyrus = 1
              print("Congratulation! You now have the color of violet!")
              COLORS.append("VIOLET")
              break
            else:
              print("You decided to dabble a little, so you left the [Papyrus] there and went outside again ...but at the end you gonna finish it.")
              continue

def violet_senate(counter):
  global violet_first_time_senate
  global violet_senate_knock
  if violet_first_time_senate == 1:
    violet_first_time_senate = 0
    violet_senate_description(counter)
  else:
    if violet_senate_knock == 0:
      print("You came to the [House].")
    else:
      print("You came to the [Senate].")
  violet_senate_direction(counter)
  
  violet_forum(counter)

################################### End of Violet Section ################################

################################## Start of Orange Section ##############################
def print_intro():  # This function print introduction
    print("\nWalking towards the door, you remind yourself of your important mission: ")
    print("Collect All The Colors")
    input("""\nYou slowly open the orange door, and step out into the unknown.
Immediately, a wave of heat washes over you, and furthermore,
a surprising sight sweeps you off your feet.
[Press enter to continue]""")
    print("""\nA sea of rocky orange floods your vision as
a leviathan-like canyon soars tremendously above you. 
Instinctively, you turn around and reach for the door. 
As soon as you touch its handle however,
the entrance crumbles into a pile of red dirt. A deep sigh 
leaves your lungs, and recedes into the rushing wind.""")


def look_around_starting_point():
    # Helper function of get_first_direction
    direction = ""
    while direction == "":
        print("""\nYou scan your surroundings. 
To your south lies an immense cliff, with steep dangerous slopes.
To your east is a bending river with emerald waters, which you could easily follow.
To your west is a meadow, which stretches infinitely towards the dusty horizon.
To your north sits a magnificent palace, made of orange and blue marble, with an wide entrance to a dark room.
                    """)
        direction = input("Where do you want to go?\nDirection: ").upper()
        while direction != "NORTH" and direction != "SOUTH" and direction != "EAST" and direction != "WEST":
          if direction:
              if direction.split()[0] == "GO":
                  direction = direction.replace("GO", "").strip()
              if direction:
                  direction_north = direction[0] == "N" or "PALACE" in direction
                  direction_south = direction[0] == "S" or "CLIFF" in direction
                  direction_east = direction[0] == "E" or "RIVER" in direction
                  direction_west = direction[0] == "W" or "MEADOW" in direction
                  if direction_north or direction_south or direction_east or direction_west:
                        if direction_north:
                            direction = "NORTH"
                        elif direction_south:
                            direction = "SOUTH"
                        elif direction_east:
                            direction = "EAST"
                        elif direction_west:
                            direction = "WEST"
              else:
                  print("Many apologies, but I don't quite understand. Perhaps we should look around again.")
          else:
              print("Indecisive I see: Let's head North!")
              direction = "NORTH"
    return direction


def get_first_direction():  # Gets the first direction from user
    answer = input("\nWhat do you want to do now? ")

    answer, answer_list, direction = answer.upper(), answer.split(), ""
    return_to_room, exit = ["EXIT", "LEAVE"], False

    if answer in return_to_room:
      yes_or_no = input("Are you sure you want to leave this room? ").upper()
      if "Y" in yes_or_no:
        print("Ok, returning to main room...")
        print()
        exit = True
      else:
        print("Well, I am glad you decided to stick around and explore!", end="")
    
    elif "GO" in answer:
        print("I think it would be a good idea to look around before we go anywhere!")

    elif "DIE" in answer:
        print("You die. Game over.")
        time.sleep(10)
        print("Just joking. You quickly overcome your existential despair", end=" ")
        print("and decide to examine this foreign landscape")
    elif answer == "":
        print("You are indecisive I see... perhaps we should look around the landscape.")

    else:
        look_around_suggestion = "I don't think you should {}! Perhaps we should examine our environment instead:"
        print(look_around_suggestion.format(answer.lower()))

    if not exit:
      direction = look_around_starting_point()

    return exit, direction


def get_sword_or_axe(string, swords, axes):
    get_what = input(f"What do you want to {string}? ").upper()
    if "SWORD" in get_what:
        print("ok")
        swords += 1
    elif "AXE" in get_what:
        print("ok")
        axes += 1
    else:
        print("I am sorry but I do not see any {} to {}".format(get_what.lower(), string))
    return swords, axes


def palace_intro():
    print("""\nYou head north into the mysterious building.
As soon as you set foot on its stone floors, a door slams shut behind you
and a two lines of torch lights are set ablaze, illuminating the room.\n""")
    print("""You are in a great hall! [AXES] and [SWORDS] line each wall
and a grand staircase leads up to what looks like a treasure room!""")


def palace_main():
    swords, axes = 0, 0
    stairs, choice = input("What do you want to do? ").upper(), 0
    get_list = ["GRAB", "TAKE", "SNATCH", "GET", "INVENT"]
    have_weapon = False

    while stairs != "STAIRCASE":
        if stairs and choice < 2: 
          for i in range(5):
              if get_list[i] in stairs:
                  swords, axes = get_sword_or_axe(get_list[i].lower(), swords, axes)
                  choice, have_weapon = choice+1, True
          if swords == 1:
            print("""You check your watch and realize there is no time to waste!
You dart up the stairs and run into the treasure room sword in hand.""")
            stairs = "STAIRCASE"
          elif axes == 1:
            print("""You check your watch and realize there is no time to waste!
You dart up the stairs and run into the treasure room axe in hand.""")
            stairs = "STAIRCASE"
        elif "STAIR" in stairs or "TREASURE" in stairs or "UP" in stairs or "ENTER" in stairs or "ROOM" in stairs:
            stairs = "STAIRCASE"
        elif "LEAVE" in stairs or "EXIT" in stairs or "GET OUT" in stairs:
            print("\nYou struggle your hardest to open the granite door, but doesn't budge")
            stairs = input("Now what do you want to do? ").upper()
            choice += 1
        elif choice > 2:
            print(f"""You check your watch and realize there is no time to waste, especially not to try to
{stairs.lower()}! You dart up the stairs and run into the treasure room.""")
            stairs = "STAIRCASE"
        else:
            stairs = input("Sorry, I didn't quite catch that, please re-enter choice: ").upper()
        choice += 1

    return swords, axes, have_weapon


def use_weapon_to_end_game(weapon):
    print(f"""Although the environmentalist within you abhors this idea, desparate situations call for desparate action!
Using your {weapon}, you chop down the tree and triumphantly 
take some delicious oranges!""")
    print("Confetti rains from the cloudless sky, and you float upwards out of the")
    print("orange arena, and return to the room with six doors")
    return True

def throw_weapon_to_end_game(weapon):
    print(f"What a great idea! You muster all your strength and throw your {weapon} at the tree.")
    print("You hit a ripe and almost perfect orange, except for a small bruise on the side")
    print("Confetti rains from the cloudless sky, and you float upwards out of the")
    print("orange arena, and return to the room with six doors")
    return True

def jump_to_end_game(weapon):
    print(f"What a great idea! You squat down and jump up as high as you can, exteneding your {weapon} at the lowest branch of the tree.")
    print("Success! You knock off a ripe and almost perfect orange, except for a small bruise on the side")
    print("Confetti rains from the cloudless sky, and you float upwards out of the")
    print("orange arena, and return to the room with six doors")
    return True

def east_function(swords, axes, have_weapon):
    direction = ""
    print("You reach the river and drink some of its sparking water to cool off")
    print("You continue down this path and see a beautiful tree, with filled with [ORANGES]")
    print("It looks like your quest is nearly complete!")
    action = input("What do you want to do? ").upper()
    game_over = False
    loop_executed = False
    while not loop_executed:
        if "ORANGE" in action:
            loop_executed = True
            if not have_weapon:
                print("You try to grab the oranges, but even the lowest bough is too high to reach!")
                print("You trudge back along the river in disappointment, wishing you were only slightly taller.")
                direction = look_around_starting_point()
            else:
                get_orange = input("How do you want to get the oranges? ").upper()
                chopping_list = ["CHOP", "ATTACK", "CUT", "SLICE"]
                throwing_list = ["THROW", "AIM", "HIT", "REACH"]
                while not game_over:
                  if get_orange:
                    if get_orange.split()[0] in chopping_list:
                        print(get_orange.split()[0].lower(), "down the orange tree with what?", end="")
                        weapon = input().upper()
                        if "SWORD" in weapon or "AXE" in weapon or "WEAPON" in weapon:
                            game_over = use_weapon_to_end_game(weapon.lower())
                    if "USE" in get_orange:
                      get_orange = input("Use what? ").upper()
                    elif "SWORD" in get_orange or "AXE" in get_orange:
                        if "SWORD" in get_orange:
                            weapon = "sword"
                        else:
                            weapon = "axe"
                        what_to_do = ""
                        while what_to_do == "":
                          what_to_do = input(f"What do you want to do with your {weapon}? Enter one word: ").upper()
                          if what_to_do in chopping_list:
                            game_over = use_weapon_to_end_game(weapon)
                          elif what_to_do in throwing_list:
                              game_over = throw_weapon_to_end_game(weapon)
                          elif "JUMP" in what_to_do or "REACH" in what_to_do:
                              game_over = jump_to_end_game(weapon)
                          else:
                            what_to_do = ""
                    elif "CLIMB" in get_orange.split()[0] or "UP" in get_orange.split()[0]:
                        print("You try to climb up the tree, but the weapon you are carrying weighs you down")
                        print("Perhaps you should try something else?")
                        get_orange = input("Enter action: ").upper()
                    elif get_orange[0] in throwing_list:
                      weapon = input("What do you want to throw?").lower()
                      while weapon != "sword" or weapon != "axe":
                        weapon = input("Perhaps you should throw something else...\nThrow: ").lower()
                      game_over = throw_weapon_to_end_game(weapon)
                    elif get_orange[0] == "JUMP":
                      game_over = jump_to_end_game
                    else:
                        print("Perhaps you could try something else?")
                        get_orange = input("Enter action: ").upper()
                  else:
                    get_orange = input("Please enter valid action: ")
        elif "RETURN" in action or "LEAVE" in action or "GO BACK" in action:
            print("You decide to return back to you starting point.")
            direction = look_around_starting_point()
        elif "CLIMB" in action or "UP" in action:
            print("You try to climb up the tree, but the weapon you are carrying weighs you down")
            while "ORANGE" not in action:
                action = input("What are you trying to get again?").upper()
        elif "ORANGE" not in action:
            while "ORANGE" not in action and "LEAVE" not in action:
                action = input("I am not sure I understand... can you rephrase that?").upper()

    return direction, game_over


def facing_dragon(swords):
    print("\nYou enter the misty room, and a towering pile of treasure awaits you! Unfortunately")
    print("after taking two steps forward you hear a tremendous ROAR, and a burst of flame nearly engulfs you!")
    print("You quickly realize there is a dragon guarding the treasure, what should you do?")
    kill_dragon = False
    while not kill_dragon:
        attack_dragon = input("Action: ").upper()
        if "HANDS" in attack_dragon:
          print("I don't think that will work out too well. Perhaps try another action? (Try single words)")
        elif "ATTACK" in attack_dragon or "USE" in attack_dragon or "SWORD" in attack_dragon or "AXE" in attack_dragon or "KILL" in attack_dragon or "HIT" in attack_dragon:
            if "USE" in attack_dragon:
                weapon = input("Use what?").lower()
            elif swords >= 1:
                weapon = "sword"
            else:
                weapon = "axe"
            kill_dragon = True
            print(f"\nWhat a good idea! You skillfully attack the dragon with your steel {weapon}")
            print("and after a few minutes of fearless and ferocious fighting, you win!")
            print("However... after scouring the heap of golden treasure, you can't find anything orange!")
            print(f"You escape through a hidden window, empty-handed except for a blood-stained {weapon} strapped to your back")
            print("\"Back to the beginning I guess\" you say, dusting yourself off and looking around.")
            direction = look_around_starting_point()
        elif "CLIMB" in attack_dragon:
            print("You have trouble climbing out of bed each morning and you think you can climb a dragon!")
        elif "HUG" in attack_dragon:
            print("How sweet! Unfortunately, the dragon thinks you are just as sweet... to eat")
        else:
            print(f"Hmm... I am not sure if you try to {attack_dragon.lower()}, it will work. Perhaps try something else?")
    return direction


def canyon_function(counter):
    swords, axes, game_over = 0, 0, False
    print_intro()
    exit, direction = get_first_direction()
    have_weapon = False
    if exit:
      return counter, game_over

    while not game_over:
        if direction == "NORTH":
            palace_intro()
            swords, axes, have_weapon = palace_main()
            have_weapon = False;
            if swords == 0 and axes == 0:
                print("""You enter the misty room, and a towering pile of treasure awaits you! Unfortunately
after taking two triumphant steps forward, you hear a earth-shaking ROAAAAAAAR behind you.
You run back into the main hall, shaking with fear, and hide next to some [AXES] and [SWORDS].""")
                while swords == 0 and axes == 0:
                    have_weapon, swords, axes = palace_main()
                direction = facing_dragon(swords)
            else:
                direction = facing_dragon(swords)
        elif direction == "SOUTH":
            print(
                "Hmm... that path looks pretty dangerous, and last I checked you are not a professional canyon climber!")
            print("Perhaps we should go another direction?")
            direction = look_around_starting_point()
        elif direction == "WEST":
            print("You head west into the meadow.")
            print("After traveling several miles under the scorching sun, you get tired of the heat and")
            print("decide to return to your starting point. Perhaps you should get some water from the river?")
            direction = look_around_starting_point()
  
        elif direction == "EAST":
            direction, game_over = east_function(swords,axes,have_weapon)
    
    return counter, game_over


def print_rainbow():
  print("""                                                                                                    
                                             ############################.                          
                                    #############################################                   
                              ##########*//////////////////////////////###############              
                         ########//////////////,.........,*///////////////////############          
                     ,######*//////*,................................*////////////*##########       
                  .#####//////*........,((((((((((((((((((((/..............///////////(########     
                #####/////......*(((((((((((((((((((((((((((((((((((...........///////////#######   
              #####////.....(((((((%%%%%%%%%%%%%%%%%%%%%%%%%%((((((((((((........../////////####### 
            ####*///....(((((%%%%%%%%#################%%%%%%%%%%%%((((((((((........./////////(####.
           ###*//*...,((((%%%%##############################%%%%%%%%%#(((((((((.........////////(#  
         ####///...((((%%%%#####                     (##########%%%%%%%%%((((((((.........////////  
        ###///...(((%%%%###                               #########%%%%%%%%((((((((........,////*   
       ###///...(((%%####                                    ########%%%%%%%%((((((((.......        
      ..    ...((%%. ..                                        %#######%%%%%%%%((((((((....         
   .                     .                                           ####%%%%%%%((((((((.. )""")
####################### End of Orange Section ##########################################

################################### Start of Blue Section ################################
def print_one(text):
    sys.stdout.write("\r" + "\r") 
    sys.stdout.flush() 
    for c in text:
        sys.stdout.write(c)
        sys.stdout.flush()
        time.sleep(0.01)
        
def snowy_forest(counter):
    global blue
    print_one('You are standing in the middle of a snowy forest, the ground and all the trees are covered by thick snow.\n'
             'How could here be something blue?\n')
    print_one('Your task: find three pieces of blue to get the blue color\n')
    str_1 = ('What do you want to do?\na.Lay down on the snow and sleep.\n'
    'b.Build a snowman\nc.I\'m so cold, I want to find a place to get some hot coco.\n')
    op_1 = input(str_1)
    while(op_1 != 'quit'):
        if op_1 == 'a':
            print_one('You closed your eyes, and ...\n')
            time.sleep(2)
            print_one('zzZZ...zzZZ\n')
            time.sleep(3)
            print_one('It is so cold that you dead in sleep. You should never make such a decision! Be smarter next time.\n')
            main()
        elif op_1 == 'b':
            print_one('Such a great snowman! You are an artist. Now let\'s find a carrot for the lovely snowman as nose.\n')
            time.sleep(2)
            print_one('Look! Here is a little cottage, let\'s get in there.\n')
            blue_cottage()
        elif op_1 == 'c':
            print_one('Look! Here is a little cottage, let\'s get in there.\n')
            blue_cottage()
    return counter

def blue_cottage():
    global blue
    global blueberry
    global bluebell
    print_one('You walk into that little cottage. It\'s so warm inside, with fire silently burning in the grate, and a grandma sitting in front of the fire and knitting.\n')
    str_cottage = ('What do you want to do?\n'
                   'a.Check the cottage.\n'
                   'b.Talk to grandma.\n'
                   'c.Quit the cottage\n')
    cottage_op = input(str_cottage)
    while cottage_op != 'c':
        if cottage_op == 'a':
            print_one('There is a full basket with berries on the table.\n')
            print_one('Do you want to taste?\n'
                      '\'y\' or \'n\'\n')
            taste_op = input()
            if taste_op == 'y':
                print_one('You picked a blueberry, it was so sweet!\n')
                if blueberry == 0:
                    blueberry += 1
                    blue.append('blueberry')
                check_blue()
            cottage_op = input(str_cottage)         
        elif cottage_op == 'b':
            print_one('\"Ohh my dear kid, isn\'t it cold outside? Come and get some hot coco!\"\n')
            print_one('Do you want to drink the coco?\n'
                      '\'y\' or \'n\'\n')
            coco_op = input()
            if coco_op == 'y':
                
                print_one('You said thank you grandma, and take the cup of hot coco.\n'
                          'The cup is so exquisite, decorated with patter ns of orchid and blubell.\n'
                          'The sweet and hot coco makes you feel so warm.')
                if bluebell == 0:
                    bluebell += 1
                    blue.append('bluebell')
                check_blue()
            cottage_op = input(str_cottage)
        else:
            print_one('Hey dear, I\'m expecting a valid answer.')
            cottage_op = input(str_cottage)
    else:
        out_cottage()

def out_cottage():
    global blue
    global sky
    global dog_eye
    print_one('You are standing outside of the cottage. You can see a tiny lake freezed at the back of the cottage, and next to it is a doghouse.\n')
    str_out_cottage = ('What do you want to do?\n'
                       'a.Go skiing on the freezing lake!\n'
                       'b.Where\'s the doggie?\n'
                       'c.It\'s so cold outside! I want to get back to the cottage.\n')
    out_co_op = input(str_out_cottage)
    while out_co_op != 'c':
        if out_co_op == 'a':         
            print_one('You are skiing on the ice surface, so free as a bird. But suddenly, Ouch! You fell on the ice.\n'
                      'Lying on the ice, you look up to the sky -- it looks like a giant light blue canvas.\n ')
            if sky == 0:
                sky += 1
                blue.append('light blue sky')
            check_blue()
            out_co_op = input(str_out_cottage)
        elif out_co_op == 'b':
            print_one('The little doggie is playing with snow! Do you want to play with it?\n'
                      '\'y\' or \'n\'\n')
            dog_op = input()
            if dog_op == 'y':
                print_one('The doggie is so happy that you play with it! You notice that is has clear eyes like blue gems.\n')
                if dog_eye == 0:
                    dog_eye += 1
                    blue.append('dog\'s eyes')
                check_blue()
            out_co_op = input(str_out_cottage)
        else:
            print_one('Hey dear, I\'m expecting a valid answer.')
            out_co_op = input(str_out_cottage)
    else:
        blue_cottage()


def check_blue():
    global blue
    if len(blue) >= 3:
        blue_color()

def blue_color():
    global blue
    global COLORS
    COLORS.append('BLUE')
    print(f'Congratulations! You have collected {len(blue)} pieces of blue: {blue}, and the color Blue is added to your pocket.')
    main()

#def blue(counter):
#  COLORS = []
blue = []
blueberry = 0
bluebell = 0
sky = 0
dog_eye = 0
#'''get three things in the blue then append to color list'''
#  snowy_forest(counter)
################## End of Blue Section ####################

################## Start of RED Magical Forest Section ####################
# tracks the user's toolbag
forest_tool_rod = 0
# tracks the user's current location
forest_loc_start = 1
forest_loc_river = 0

def forest_start_instruction(counter):
    global forest_loc_start 
    global forest_loc_river 
    global forest_tool_rod
    result = 0
    print(
        '''
You find yourself standing in a big forest. 
On the ground, you found a small [rod].
You noticed that small yellow [bird] is looking at you, singing beautiful songs. Will she be willing to talk to you...?
On your [right], there is a [river]. The shimmering river reflects the setting sun on the horizon.

Hint: Try typing the input in such format - "Action + "Place/Object/Direction".
List of actions: "go", "talk", "take", "use"
List of place/object/direction: "river", "bird", "rod","left/right"

What would you like to do?

        '''
    )
    while True:
        user_choice = input()
        counter += 1
        if user_choice == 'take rod':  # Take #1: Take rod
            print(
                '''
You put a small rod in your bag. Is there any place for fishing...?
                ''')
            forest_tool_rod = 1
            break
        elif (user_choice == 'go river' or user_choice == 'go right'):
            forest_loc_river = 1
            forest_loc_start = 0
            break
        elif (user_choice == 'talk bird'):
            print(
                '''
The bird said: "My hint is, find something to fish the RED FISH!!"
                ''')
            break
        elif (user_choice == 'exit'):
          result = -20
          return counter, result;
        else:  # Invalid input -> prompt again
            print(
                '''
This is not a valid input. Try typing the prompt in such format - "Action + "Place/Object/Direction".
List of actions: "go", "talk", "take"
Try enter again!
                '''
            )
    return counter, result;

def forest_start_instruction_withRod(counter):
    global forest_loc_start 
    global forest_loc_river 
    global forest_tool_rod
    result = 0
    print(
        '''
You find yourself standing in a big forest. 
You noticed that small yellow [bird] is looking at you, singing beautiful songs. Will she be willing to talk to you...?
On your [right], there is a [river]. The shimmering river reflects the setting sun on the horizon.
What would you like to do?
        '''
    )
    while True:
        user_choice = input()
        counter += 1
        if (user_choice == 'go river' or user_choice == 'go right'):
            forest_loc_river = 1
            forest_loc_start = 0
            break
        elif (user_choice == 'talk bird'):
            print(
                '''
The bird said: "My hint is, find something to fish the RED FISH!!"
                ''')
            break
        elif (user_choice == 'exit'):
          result = -20
          return counter, result;
        else:  # Invalid input -> prompt again
            print(
                '''
This is not a valid input. Try typing the prompt in such format - "Action + "Place/Object/Direction".
List of actions: "go", "talk", "take", "use"
Try enter again!
                '''
            )
    return counter, result;


def forest_river_instruction(counter):
    global forest_loc_start 
    global forest_loc_river 
    global forest_tool_rod
    result = 0
    print(
        '''
You are standing in front of the river. The water is so clear that you can almost see the shadow of fish at the bottom.
What would you like to do?
        '''
    )
    while True:
        user_choice = input()
        counter += 1
        if (user_choice == 'go back' or user_choice == 'go left'):
            forest_loc_river = 0
            forest_loc_start = 1
            break
        elif (user_choice == 'use rod'):
            if (forest_tool_rod == 1):
                print('You begin to fish.')
                counter, result = forest_river_fish(counter)
            else:
                print('You do not have a rod in your bag. Go find a rod!')
            break
        elif (user_choice == 'exit'):
            result = -20
            return counter, result;
        else:  # Invalid input -> prompt again
            print(
                '''
This is not a valid input. Try typing the prompt in such format - "Action + "Place/Object/Direction".
List of actions: "go", "talk", "take", "use"
Try enter again!
                '''
            )
    return counter, result;


def forest_river_fish(counter):
    global forest_loc_start 
    global forest_loc_river 
    global forest_tool_rod
    result = 0
    print(
        '''
You waited for 1s...2s...3s...
You got a boot! Ah - why is it not a fish...!
Do you want to try again? (Enter "y" or "n")
        '''
    )
    user_choice = input()
    counter += 1
    if (user_choice == 'y'):
        print(
            '''
You waited for 1s...2s...3s...4s...5s...
Woohoo! There is a big RED snapper fish! It seems that you have found the color "RED" in the forest. 
You can enter "exit" to go back to the room and continue to find the rest of colors.
            '''
        )
        user_choice == input()
        counter += 1
        if user_choice == 'exit':
            result = -20
            return counter, result;
    elif (user_choice == 'n'):
        print(
            '''
You hear the bird saying: "Hold on! Don't give up! You are about to get the fish!"
You waited for 1s...2s...3s...4s...5s...
Woohoo! There is a big RED snapper fish! It seems that you have found the color "RED" in the forest. 
You can enter "exit" to go back to the room and continue to find the rest of colors.
            '''
        )
        user_choice == input()
        counter += 1
        if user_choice == 'exit':
            result = -20
            return counter, result;
    elif (user_choice == 'exit'):
      result = -20
      return counter, result;
    else:  # Invalid input -> prompt again
        print(
            '''
This is not a valid input. Try typing the prompt in such format - "Action + "Place/Object/Direction".
List of actions: "go", "talk", "take", "use"
Try enter again!
            '''
        )
    result = 10
    return counter, result;

def magical_forest(counter):
    nCnt = counter
    success = False
    while True:
        if forest_loc_start == 1 and forest_loc_river == 0:
            if forest_tool_rod == 0:
                nCnt, res = forest_start_instruction(nCnt)
                if res == -20:
                  break
            else:
                nCnt, res = forest_start_instruction_withRod(nCnt)
                if res == -20:
                  break
        elif forest_loc_start == 0 and forest_loc_river == 1:
            nCnt, res = forest_river_instruction(nCnt)
            if res == -20:
              break
            if res == 10: #when the user catches the fish successfully
              success = True
              break      
    return nCnt, success;
################## End of RED Magical Forest Section ####################
################## Start of GREEN Magical Garden Section #################

def magical_garden(counter):
    choicestree = ['inspect tree', 'back to garden']
    choices1 = ['go tree', 'talk to woman', 'take hummingbird']
    exit = 'exit (will take you to first room with 6 doors)'

    def woman(counter):
        print('You approach the beautiful lady. She slowly turns around and motions for you'
              'to sit next to her. She offers you a rose.')
        print('COUNTER:', counter)
        print('CHOICES: take rose, refuse rose, ', end='')
        print(exit)
        choice = input('> ')
        while choice != 'take rose' and choice != 'exit' and choice != 'refuse rose':
            choice = input('incorrect input, try again: ')
        if choice == 'take rose':
            print('You take the rose. It\'s beautiful—the woman whispers to you "Thank the tree".')
            choicestree.append('place rose in vase')
            print('COUNTER: ', counter)
            print('CHOICES: back to garden, toss flower')
            choice = input('> ')
            if choice == 'toss flower':
                print('''You toss the flower at the woman. She shape-shifts into a hydra with
                       9 heads and cuts your head off. How could you be so disrespectful to a 
                       goddess?''')
                counter = 0
                return counter
            if choice == 'back to garden':
                magical_garden_rose(counter)
                print('You are back in the garden.')
                print('COUNTER: ', counter)
                print('CHOICES: ', end='')
                for choice in choices1:
                    print(choice, end='')
        if choice == 'refuse rose':
            print('''
            You refuse the rose. The woman appears hurt by this and begins to walk away. All of a 
            sudden, she turns around and looks into your eyes. For some reason, your legs refuse to
            move and you are rooted in place. The woman's eyes light into an emerald glow and 
            she speaks seriously: "Your incompetence isn't welcome in the holy garden. Weak one,
            you must die." Her body turns entirely green, radiating some sort of energy. Your vision
            blurs and you crumple to the ground—death is coming.
            ''')
            counter = 0
            return counter
        if choice == 'exit':
            main()

    def magical_garden_mid(counter):

        print('''You are standing back in the garden. The tree is still in the distance. The lady is
                  on the diamond bench. Hummingbirds continue buzzing around the garden.''')

        print('COUNTER: ', counter)
        print('CHOICES: ', end='')
        for choice in choices1:
            print('{}, '.format(choice), end='')
        choice = input('> ')
        while choice not in choices1:
            choice = input('Incorrect input, try again: ')
        if choice == 'go tree':
            counter -= 1
            tree(counter)
        if choice == 'take hummingbird':
            hummingbird(counter)
        if choice == 'exit':
            main()
        if choice == 'talk to woman':
            woman(counter)

    def magical_garden_rose(counter):

        print('''You are standing back in the garden. The tree is still in the distance. The lady is
              no where to be seen. Hummingbirds still buzz around the garden.''')
        choices1.remove('talk to woman')
        print('COUNTER: ', counter)
        print('CHOICES: ', end='')
        for choice in choices1:
            print('{}, '.format(choice), end='')
        print(exit)
        choice = input('> ')
        while choice not in choices1:
            choice = input('Incorrect input, try again: ')
        if choice == 'go tree':
            counter -= 1
            tree(counter)
        if choice == 'take hummingbird':
            hummingbird(counter)
        if choice == 'exit':
          main()

    def tree(counter):
        print('''
        After a long walk, you approach the tree. It's a beautiful tree; each leaf if completely
        unique. The trunk appears to be shimmering green (like an emerald). Everything around
        the tree is tinted green from the reflection. The source of this green color must be nearby.
        Perhaps, it's within the tree. There's a vase at the base of the tree''')
        print('COUNTER: ', counter)
        print("CHOICES: ", end='')
        for choice in choicestree:
            print('{}, '.format(choice), end='')
        print(exit)
        choice = input('> ')
        while choice not in choicestree and choice != exit:
            choice = input('Incorrect input, try again: ')
        if choice == 'inspect tree':
            counter -= 1
            print(''' Upon closer inspection of the tree, the vase is a small, empty, and green.
            Maybe filling the vase with something would be nice?''')
            print('COUNTER: ', counter)
            print("CHOICES: ", end='')
            for choice in choicestree:
                print('{}, '.format(choice), end='')
            print(exit)
            choice = input('> ')

        if choice == 'place rose in vase':
            print(''' 
            You place the rose that the woman gave you in the vase. The green bark of the tree 
            starts swirling vigorously, and a bright green leaf falls onto the ground directly
            in front of you. Upon closer inspection of the leaf, it has an inscription on it: 
            "The holy garden thanks you for your generosity." This leaf will provide you with endless
            green power.''')
            print(''' You have successfully found the green beacon! Congratulations, leaving garden now.
            ''')
            counter -= 1
            COLORS.append('GREEN')
            counter = 40
            return counter
        if choice == 'back to garden':
            counter -= 1
            magical_garden_mid(counter)
        if choice == 'exit':
          main()

    def magical_garden_start(counter):
        counter -= 1

        print('''    You enter the door with an orchid pinned to it. Immediately, light floods your eyes.
              You gasp—this is the most beautiful garden you have ever seen. Hummingbirds buzz 
              around what appears to be an infinite amount of flowers. In the distance, you see a 
              large willow tree. Behind you, a bright emerald green river flows vigorously through
              a bamboo forest. The most attractive woman you have ever seen sits on a diamond 
              bench, observing the river. She clearly notices you standing, but makes no attempt
               at hospitality.''')
        print("COUNTER:", counter)
        print("CHOICES: ", end='')
        for choice in choices1:
            print('{}, '.format(choice), end='')
        print(exit)
        choice = input("> ")
        while choice != 'exit' and choice not in choices1:
            choice = input('Incorrect input, try again: ')
        if choice == 'exit':
            counter -= 1
            return counter
        if choice == 'go tree':
            counter -= 1

            tree(counter)
        if choice == 'exit':
          main()
        if choice == 'talk to woman':
            counter -= 1
            woman(counter)
        if choice == 'take hummingbird':
            counter -= 1
            hummingbird(counter)

    def hummingbird(counter):
        print('The hummingbirds are buzzing around the flowers. Reaching out, you manage to '
              'grab one of them. Immediately, you realize this was a mistake. The '
              'hummingbird\'s wings are made of razor sharp fiberglass... your hands erupt '
              'into a fountain of red—there\'s simply too much blood. You die from blood loss'
              '. Don\'t mess with the hummingbirds.')
        counter = 0
        return counter

    magical_garden_start(counter)


#################################### end of magical garden section #########################
def main():
  counter = 40
  print_rainbow()
  while len(COLORS) < 6 and counter > 0:
    print('You stumble awake from a long sleep. Looking around, there appear to be 6 doors '
             'in a medium-sized room. After closer investigation, the doors appear different.'
             '\nDOOR 1: White sand is apparent on the ground near the door\nDOOR 2: Three massive'
             ' leaves are crumpled near this door\nDOOR 3: Ice fully covers the door handle'
             ' and snow is on the ground\nDOOR 4: This door has a solid gold door handle\nDOOR 5: '
             'The ground around this door appears dry and cracked\nDOOR 6: A beautiful orchid'
             ' flower is pinned to this door.')
    choice = input('Which door do you choose? ')
    while (not choice.isdecimal()) or (int(choice) > 6):
      choice = input('Try again, incorrect input: ')
    if int(choice) == 1:
      result = desert(counter);
      counter = result[0];
      if result[1]: 
        COLORS.append('YELLOW')
    elif int(choice) == 2:
        counter, result_Red = magical_forest(counter)
        if result_Red:
          COLORS.append('RED')
    elif int(choice) == 3:
          snowy_forest(counter)
    elif int(choice) == 4:
        counter = violet_forum(counter)
    elif int(choice) == 5:
        counter, game_won = canyon_function(counter)
        if game_won:
          COLORS.append("ORANGE")
    elif int(choice) == 6:
        print('Remember, you\'re looking for the GREEN COLOR!')
        counter = magical_garden(counter) 
        main()

  if COLORS[0] == 'RED' and COLORS[1] == 'ORANGE' and COLORS[2] == 'YELLOW' and COLORS[3] == 'GREEN' and COLORS[4] == 'BLUE' and COLORS[5] == 'VIOLET':
    print('CONGRATULATIONS! You completed a perfect rainbow.')
  else:
    if len(COLORS) == 6:
      print('''
      Congratulations! Even though your rainbow wasn't in order, you still found all of the colors—
      which is very impressive. You should be proud!
      ''')
    else:
      print('You failed to find every color :( sorry')



main()
# Out:
#
#                                              ############################.
#                                     #############################################
#                               ##########*//////////////////////////////###############
#                          ########//////////////,.........,*///////////////////############
#                      ,######*//////*,................................*////////////*##########
#                   .#####//////*........,((((((((((((((((((((/..............///////////(########
#                 #####/////......*(((((((((((((((((((((((((((((((((((...........///////////#######
#               #####////.....(((((((%%%%%%%%%%%%%%%%%%%%%%%%%%((((((((((((........../////////#######
#             ####*///....(((((%%%%%%%%#################%%%%%%%%%%%%((((((((((........./////////(####.
#            ###*//*...,((((%%%%##############################%%%%%%%%%#(((((((((.........////////(#
# ...
