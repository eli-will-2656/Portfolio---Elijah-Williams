# %% [markdown]
# # Welcome to Our Met Objects Data Analysis Project (Elijah / Isaiah)
# ### Initialization
# ##### First, we imported pandas and set the display settings.

# %%
import pandas as pd
pd.options.display.max_rows = 100
pd.set_option('max_columns', None)

# %% [markdown]
# ##### Then we created the dataframe object (df) and look at its basic contents.

# %%
df = pd.read_csv("Downloads/MetObjects.txt", delimiter=",", encoding='utf-8', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e9df7320326b> in <module>()
# ----> 1 df = pd.read_csv("Downloads/MetObjects.txt", delimiter=",", encoding='utf-8', low_memory=False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Downloads/MetObjects.txt'

# %%
df.head()

# %%
df.describe(include="all")

# %%
df.count() / len(df)

# %% [markdown]
# ##### Just for fun, here is a sample of our data.

# %%
df.sample(5)

# %% [markdown]
# ##### Now that we have our basic setup, we can begin asking all sorts of questions:

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# ##### (1) What is the oldest object within the Met's collection, and which department does it belong to?

# %%
df.sort_values(by='Object Begin Date', ascending=True).head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7f15e4d3e754> in <module>()
# ----> 1 df.sort_values(by='Object Begin Date', ascending=True).head(1)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ##### (2) What was the first (recorded) object that was acquired by the Met, and when?

# %%
df.sort_values(by='AccessionYear', ascending=True).head(1)
# Out:
#        Object Number  Is Highlight  Is Timeline Work  Is Public Domain  \
# 138941          70.1          True              True              True
#
#         Object ID Gallery Number           Department AccessionYear  \
# 138941     239584            169  Greek and Roman Art          1870
#
#                  Object Name                             Title Culture  \
# 138941  Sarcophagus, garland  Marble sarcophagus with garlands   Roman
#
#          Period Dynasty Reign Portfolio Constituent ID Artist Role  \
# 138941  Severan     NaN   NaN       NaN            NaN         NaN
#
#        Artist Prefix Artist Display Name Artist Display Bio Artist Suffix  \
# 138941           NaN                 NaN                NaN           NaN
#
#        Artist Alpha Sort Artist Nationality Artist Begin Date Artist End Date  \
# 138941               NaN                NaN               NaN             NaN
#
#        Artist Gender Artist ULAN URL Artist Wikidata URL       Object Date  \
# 138941           NaN             NaN                 NaN  ca. A.D. 200–225
#
#         Object Begin Date  Object End Date                Medium  \
# 138941                200              225  Marble, Proconnesian
#
#                                                Dimensions  \
# 138941  Overall: 53 x 88in. (134.6 x 223.5cm)         ...
#
#                       Credit Line Geography Type City State County Country  \
# 138941  Gift of Abdo Debbas, 1870            NaN  NaN   NaN    NaN     NaN
#
#        Region Subregion Locale Locus Excavation River   Classification  \
# 138941    NaN       NaN    NaN   NaN        NaN   NaN  Stone Sculpture
#
#        Rights and Reproduction  \
# 138941                     NaN
#
#                                             Link Resource  \
# 138941  http://www.metmuseum.org/art/collection/search...
#
#                             Object Wikidata URL  Metadata Date  \
# 138941  https://www.wikidata.org/wiki/Q29383708            NaN
#
#                                       Repository  \
# 138941  Metropolitan Museum of Art, New York, NY
#
#                                    Tags  \
# 138941  Animals|Garlands|Hunting|Medusa
#
#                                              Tags AAT URL  \
# 138941  http://vocab.getty.edu/page/aat/300249525|http...
#
#                                         Tags Wikidata URL
# 138941  https://www.wikidata.org/wiki/Q729|https://www...

# %% [markdown]
# (3) What Egyptian Dynasties does the Met house the most objects from?

# %%
df[df['Dynasty'].notna()]['Dynasty'].value_counts()[:7].plot(kind='pie', ylabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# (4) What kind of weapons would a night guard watch out for (come Night at the Museum)?

# %%
df[df["Department"] == "Arms and Armor"]["Object Name"].value_counts()[:7]  \
.plot(kind='pie', title="Arms and Armor: Common Object Types", ylabel='')
# Out:
# <AxesSubplot:title={'center':'Arms and Armor: Common Object Types'}>

# %% [markdown]
# The Arms and Armory section of the Met is filled with a wonderful assortment of weapons and containers, including:
# (1) Tsuba (1218) - Sword gaurds to protect hand from sliding on blade
# (2) Kozuka (1088) - Japanese Knife holder
# (3) Fuchigashira (506) - Japanese Metal fitting on Sword
# (6) Kris with Sheath (152) - Indonesian assymetrical Dagger
# (7) Halberd (152) - Medieval two-handed pole weapon, consisting of axe blade and spike on long shaft

# %% [markdown]
# (5) What are the current overarching values of the medium / culture / artist nationalities?

# %%
top_15_mediums = df["Medium"].value_counts()[:15]
top_15_mediums.plot(kind="pie", title="Current Counts of Top 15 Represented Mediums")
# Out:
# <AxesSubplot:title={'center':'Counts of Top 15 Represented Mediums'}, ylabel='Medium'>

# %%
top_10_culture = df["Culture"].value_counts()[:10]
top_10_culture.plot(kind="barh", legend=True, label="# of Objects", title="Current Counts of Top 10 Represented Cultures", \
                   color=["b", "g", "gray", "gray", "gray", "r", "gray", "m", "gray", "y"])
# Out:
# <AxesSubplot:title={'center':'Counts of Top 10 Represented Cultures'}>

# %%
top_5_nationalities = df["Artist Nationality"].value_counts()[1:8]
top_5_nationalities = top_5_nationalities.drop(labels=[" | ", "French|French"]) 
top_5_nationalities.plot(kind="barh", legend=True, label="# of Objects", title="Current Counts of Top 5 Represented Artist Nationalities", \
                         color=["b", "g", "r", "m", "y"])
# Out:
# <AxesSubplot:title={'center':'Counts of Top 5 Represented Artist Nationalities'}>

# %% [markdown]
# ##### We could continue breaking apart the dataset as such, but given the scope of the data we would like to address some larger questions over time.

# %% [markdown]
# ##### Seeing as there are several columns which will not be relevant to our large-scale analysis, we can drop those values.

# %%
df = df.drop(columns=['Is Highlight', 'Is Timeline Work', 'Is Public Domain',
       'Object ID', 'Gallery Number', 'Dynasty', 'Reign',
       'Portfolio', 'Constituent ID', 'Artist Role', 'Artist Prefix','Artist Display Bio', 'Artist Suffix',
       'Artist Alpha Sort', 'Artist ULAN URL',
       'Artist Wikidata URL', 'City', 'State', 'County', 'Region',
       'Subregion', 'Locale', 'Locus', 'Excavation', 'River',
       'Rights and Reproduction', 'Object Wikidata URL',
       'Metadata Date', 'Repository', 'Tags', 'Tags AAT URL',
       'Tags Wikidata URL', 'Period', 'Artist Gender', 'Geography Type', 'Country'])

# %% [markdown]
# **Important Note**
# Columns with signficant missing values we are using:
# >|    Column    |  Null-Values(%) |
# >|    ------    | --------------- |
# >|    Culture   |.56|
# >|    Country   |.84|
# >|  Artist (info) |.42|

# %% [markdown]
# ## The Main Questions -- Adding complexity with visualizations over time

# %% [markdown]
# ### Question 1: The Journey To Two Million
# ##### What was the overall trend and the outliers in the journey over the years in amassing 2 million objects?

# %%
ax1 = df[df['AccessionYear'] != '2005-02-15'].groupby("AccessionYear")["Object Name"].count().plot(title="Annual Accessions",xlabel="   Year ",ylabel="Number of Items")

# %% [markdown]
# #### Outliers
# In the Timeseries above, there are several noticeable spikes, the most conspicuous being 1963, with over 40,000 objects being acquired. Let's investigate these outliers:
#
# |    Year    |  Number of Acquisitions |
# |    ------    | :----------: |
# |  1963  | 40333   |
# |  2011   |  18583 |
# |  2009  | 9362   |

# %% [markdown]
# **2009 - The Costume Institute**, one of the smaller departments of the Met, received a massive amount of fashionable clothing from the Brooklyn Museum, nearly 8000 items which dramatically expanded their already large collection. The Met's 4 most acquired items in 2009 were Evening Dresses (557), Hats (388), Dresses (386), and Ensemble (227)
#
# **1963 - The Department of Drawings** separated from the much larger Painting Department two years prior to this spike; perhaps the massive acquisition this year is related to "Drawings" acquistion group receiving it's own department for purchases. Greater than 95% of accessions of the Met in 1963 were Prints and Drawings, a whopping 38,000+ prints added to the Met's collection impressive collection .
#
# **2011 - Department of Greek and Roman Art** acquired 10,000 Kylix fragments, Kylix being the common type of wine-drinking cup in Anceint Greece, typically with a shallow body, and two horizonal. Greater than 95% of accession of the Met in 2011 were kyklix, amphora, or krater fragments belonging to department of Greek and Roman Art.

# %% [markdown]
# ### Question 2:
# ##### Precisely how did these differing mediums, cultures, and artist nationalities accumulate over time?
# Using cumulative sums, we can see when exactly were the formative years of the different mediums, cultures, and artist nationalities.

# %%
cultures = top_10_culture.keys().tolist()
for culture in cultures:
    tmpdf = df[df["Culture"] == culture]
    tmpdf.groupby("AccessionYear").count()["Object Number"].cumsum().plot(legend=True, label=culture, title="Cumulative Sum of Top 10 Represented Cultures Over Time").legend(bbox_to_anchor=(1,1))

# %%
nationalities = top_5_nationalities.keys().tolist()
for nationality in nationalities:
    tmpdf = df[df["Artist Nationality"] == nationality]
    tmpdf.groupby("AccessionYear").count()["Object Number"].cumsum().plot(legend=True, label=nationality, title="Cumulative Sum of Top 5 Represented Artist Nationalities Over Time").legend(bbox_to_anchor=(1,1))

# %% [markdown]
# ##### While this data gives us the general trends, it is quite disproportionate -- can we do better?

# %%
top_7_departments = df["Department"].value_counts()[:7]
departments = top_7_departments.keys().tolist()
for department in departments:
    tmpdf = df[df["Department"] == department]
    ax2 = (tmpdf.groupby("AccessionYear").count()["Object Number"].cumsum() / tmpdf.groupby("AccessionYear").count()["Object Number"].sum()) \
    .plot(style='--', legend=True, label=department, title="Cumulative Relative Frequency of Top 7 Largest Deparments Over Time").legend(bbox_to_anchor=(1,1))

# %% [markdown]
# By making this a cumulative relative frequency plot, the trends for each department become much clearer over time and we can extrapolate the most formative years for each department. The same goes for mediums:

# %%
mediums = top_15_mediums.keys()[:7].tolist()
for medium in mediums:
    tmpdf = df[df["Medium"] == medium]
    ax3 = (tmpdf.groupby("AccessionYear").count()["Object Number"].cumsum() / tmpdf.groupby("AccessionYear").count()["Object Number"] \
    .sum()).plot(style='--', legend=True, label=medium, title="Cumulative Relative Frequency of Top 7 Represented Mediums Over Time") \
    .legend(bbox_to_anchor=(1,1))

# %% [markdown]
# ### Question 3:
# ##### How do the object date vary across departments?

# %%
df_tmp = df.groupby("Department").count()
df_tmp1 = df.groupby("Department").sum()
df_tmp1["Average begin date"] = df_tmp1["Object Begin Date"] / df_tmp["Object Number"]
df_tmp1["Average end date"] = df_tmp1["Object End Date"] / df_tmp["Object Number"]
df_tmp1["Average Object Date"] = (df_tmp1["Average begin date"] + df_tmp1["Average end date"]) / 2

# %%
ax4 = df_tmp1["Average Object Date"].sort_values().plot(kind="bar", title="Average Object Date by Department") \
    .legend(bbox_to_anchor=(1,1))

# %% [markdown]
# ### Saving Our Graphs

# %%
import matplotlib.pyplot as plt
plt.tight_layout()

ax1.figure.savefig('1Annual_Accessions.pdf', format="pdf")
ax2.figure.savefig('2CMF_7-Largest-Deparments-Over-Time.pdf', format="pdf")
ax3.figure.savefig('3CMF_7-Largest-Mediums-Over-Time.pdf', format="pdf")
ax4.figure.savefig('4Average_Object-Date-by-Department.pdf', format="pdf")

# %% [markdown]
# ### (Aside)The Search for the Dutch Printmakers

# %% [markdown]
# ##### What happened to the Dutch printmakers?

# %%
df_print = df[df["Object Name"] == "Print"]
df_print.groupby("Culture").count().sort_values(by="Object Number", ascending=False).head(5)
# Out:
#                               Object Number  Is Highlight  Is Timeline Work  \
# Culture
# Japan                                  3175          3175              3175
# China                                   503           503               503
# India                                    19            19                19
# American                                  6             6                 6
# India, West Bengal, Calcutta              5             5                 5
#
#                               Is Public Domain  Object ID  Gallery Number  \
# Culture
# Japan                                     3175       3175               3
# China                                      503        503               1
# India                                       19         19               0
# American                                     6          6               2
# India, West Bengal, Calcutta                 5          5               0
#
#                               Department  AccessionYear  Object Name  Title  \
# Culture
# Japan                               3175           3103         3175   1093
# China                                503            502          503    159
# India                                 19             19           19      0
# American                               6              6            6      6
# India, West Bengal, Calcutta           5              5            5      0
#
#                               Period  Dynasty  Reign  Portfolio  \
# Culture
# Japan                           2998        0      0          0
# China                            457        0      0          0
# India                              0        0      0          0
# American                           0        0      0          0
# India, West Bengal, Calcutta       0        0      0          0
#
#                               Constituent ID  Artist Role  Artist Prefix  \
# Culture
# Japan                                   3170         3170           3170
# China                                    273          273            273
# India                                      2            2              2
# American                                   2            2              2
# India, West Bengal, Calcutta               0            0              0
#
#                               Artist Display Name  Artist Display Bio  \
# Culture
# Japan                                        3170                3170
# China                                         273                 273
# India                                           2                   2
# American                                        2                   2
# India, West Bengal, Calcutta                    0                   0
#
#                               Artist Suffix  Artist Alpha Sort  \
# Culture
# Japan                                  3170               3170
# China                                   273                273
# India                                     2                  2
# American                                  2                  2
# India, West Bengal, Calcutta              0                  0
#
#                               Artist Nationality  Artist Begin Date  \
# Culture
# Japan                                       3170               3170
# China                                        273                273
# India                                          2                  2
# American                                       2                  2
# India, West Bengal, Calcutta                   0                  0
#
#                               Artist End Date  Artist Gender  Artist ULAN URL  \
# Culture
# Japan                                    3170             36             2987
# China                                     273             23               66
# India                                       2              0                0
# American                                    2              0                1
# India, West Bengal, Calcutta                0              0                0
#
#                               Artist Wikidata URL  Object Date  \
# Culture
# Japan                                        2947         2763
# China                                          69          273
# India                                           0           19
# American                                        1            6
# India, West Bengal, Calcutta                    0            5
#
#                               Object Begin Date  Object End Date  Medium  \
# Culture
# Japan                                      3175             3175    3173
# China                                       503              503     503
# India                                        19               19      19
# American                                      6                6       6
# India, West Bengal, Calcutta                  5                5       5
#
#                               Dimensions  Credit Line  Geography Type  City  \
# Culture
# Japan                               3173         3174               0     0
# China                                503          503               0     0
# India                                 19           19               0     0
# American                               6            6               4     4
# India, West Bengal, Calcutta           5            5               0     0
#
#                               State  County  Country  Region  Subregion  \
# Culture
# Japan                             0       0        0       0          0
# China                             0       0        0       0          0
# India                             0       0        0       0          0
# American                          0       0        4       0          0
# India, West Bengal, Calcutta      0       0        0       0          0
#
#                               Locale  Locus  Excavation  River  \
# Culture
# Japan                              0      0           0      0
# China                              0      0           0      0
# India                              0      0           0      0
# American                           0      0           0      0
# India, West Bengal, Calcutta       0      0           0      0
#
#                               Classification  Rights and Reproduction  \
# Culture
# Japan                                   3175                        2
# China                                    503                        0
# India                                     19                        0
# American                                   0                        0
# India, West Bengal, Calcutta               5                        0
#
#                               Link Resource  Object Wikidata URL  \
# Culture
# Japan                                  3175                  172
# China                                   503                    0
# India                                    19                    0
# American                                  6                    1
# India, West Bengal, Calcutta              5                    0
#
#                               Metadata Date  Repository  Tags  Tags AAT URL  \
# Culture
# Japan                                     0        3175  3105          3105
# China                                     0         503   183           183
# India                                     0          19    15            15
# American                                  0           6     5             5
# India, West Bengal, Calcutta              0           5     0             0
#
#                               Tags Wikidata URL
# Culture
# Japan                                      3105
# China                                       183
# India                                        15
# American                                      5
# India, West Bengal, Calcutta                  0

# %%
percent_data = (df_print.count() / len(df_print))["Culture"] * 100
print(f"Only {percent_data:.1f}% recorded cultural values for prints.")
# Out:
# Only 3.8% recorded cultural values for prints.

# %% [markdown]
# ##### Unfortunately, the major missing value for cultural imputs was actually the also the largest section of "Object Name" -- prints. This serves as reminder of how the abscences of data can signficantly impact its portrayal. Luckily, there is another section of the data we can use:

# %%
df_print.groupby("Artist Nationality").count().sort_values(by="Object Number", ascending=False).head(14)
df_print[df["Artist Nationality"] == "Dutch"]
# Out:
# C:\Users\isaia\AppData\Local\Temp/ipykernel_27408/2478678297.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_print[df["Artist Nationality"] == "Dutch"]
#        Object Number  Is Highlight  Is Timeline Work  Is Public Domain  \
# 203164   1981.1197.2         False             False             False
# 203388   1993.1070.2         False             False             False
# 203398     1993.1112         False             False             False
# 203404       1994.17         False             False             False
# 203423    1994.110.1         False             False              True
# ...              ...           ...               ...               ...
# 376023      2014.204         False             False              True
# 389006     60.621.20         False             False              True
# 390875    54.90.1402         False             False             False
# 399753      2015.235         False             False              True
# 400806       19.12.3         False             False             False
#
#         Object ID Gallery Number           Department AccessionYear  \
# 203164     334366            NaN  Drawings and Prints          1981
# 203388     334592            NaN  Drawings and Prints          1993
# 203398     334602            NaN  Drawings and Prints          1993
# 203404     334608            NaN  Drawings and Prints          1994
# 203423     334627            NaN  Drawings and Prints          1994
# ...           ...            ...                  ...           ...
# 376023     642824            NaN  Drawings and Prints          2014
# 389006     661687            NaN  Drawings and Prints          1960
# 390875     665935            NaN  Drawings and Prints          1954
# 399753     686299            NaN  Drawings and Prints          2015
# 400806     688146            NaN  Drawings and Prints          1919
#
#        Object Name                                              Title Culture  \
# 203164       Print            Hurdy-Gurdy Player with his Dancing Dog     NaN
# 203388       Print                                  Mocking of Christ     NaN
# 203398       Print  Title page to: Tweede Reizen van den Heese De ...     NaN
# 203404       Print                                          The Storm     NaN
# 203423       Print                                 St. Jerome Reading     NaN
# ...            ...                                                ...     ...
# 376023       Print                                       The Windmill     NaN
# 389006       Print                         The Unloading of the Barge     NaN
# 390875       Print  Totius Neobelgii Nova et Accuratissima Tabula ...     NaN
# 399753       Print                                Rebecca and Eliezer     NaN
# 400806       Print             Jetée en Bois dans le Port de Honfleur     NaN
#
#        Period Dynasty Reign Portfolio Constituent ID Artist Role  \
# 203164    NaN     NaN   NaN       NaN          16386      Artist
# 203388    NaN     NaN   NaN       NaN           6920      Artist
# 203398    NaN     NaN   NaN       NaN           6910      Artist
# 203404    NaN     NaN   NaN       NaN          16258      Artist
# 203423    NaN     NaN   NaN       NaN          16229      Artist
# ...       ...     ...   ...       ...            ...         ...
# 376023    NaN     NaN   NaN       NaN          16229      Artist
# 389006    NaN     NaN   NaN       NaN          16353      Artist
# 390875    NaN     NaN   NaN       NaN           7674   Publisher
# 399753    NaN     NaN   NaN       NaN           7026      Artist
# 400806    NaN     NaN   NaN       NaN          16477      Artist
#
#        Artist Prefix             Artist Display Name  \
# 203164                               Cornelis Dusart
# 203388         After         Werner van den Valckert
# 203398                                    Jan Luyken
# 203404                        Moses van Uyttenbroeck
# 203423                Rembrandt (Rembrandt van Rijn)
# ...              ...                             ...
# 376023                Rembrandt (Rembrandt van Rijn)
# 389006                         Allart van Everdingen
# 390875                                  Carel Allard
# 399753                       Louis Fabritius Dubourg
# 400806                       Johan Barthold Jongkind
#
#                                     Artist Display Bio Artist Suffix  \
# 203164                Dutch, Haarlem 1660–1704 Haarlem
# 203388        Dutch, The Hague, 1580/85–1627 Amsterdam
# 203398            Dutch, Amsterdam 1649–1712 Amsterdam
# 203404  Dutch, The Hague ca. 1595–after 1646 The Hague
# 203423               Dutch, Leiden 1606–1669 Amsterdam
# ...                                                ...           ...
# 376023               Dutch, Leiden 1606–1669 Amsterdam
# 389006              Dutch, Alkmaar 1621–1675 Amsterdam
# 390875        Dutch, Amsterdam 1648–ca. 1709 Amsterdam
# 399753            Dutch, Amsterdam 1693–1775 Amsterdam
# 400806     Dutch, Latrop 1819–1891 La-Côte-Saint-André
#
#                      Artist Alpha Sort Artist Nationality Artist Begin Date  \
# 203164                Dusart, Cornelis              Dutch        1660
# 203388        Valckert, Werner van den              Dutch        1580
# 203398                     Luyken, Jan              Dutch        1649
# 203404         Uyttenbroeck, Moses van              Dutch        1595
# 203423  Rembrandt (Rembrandt van Rijn)              Dutch        1606
# ...                                ...                ...               ...
# 376023  Rembrandt (Rembrandt van Rijn)              Dutch        1606
# 389006          Everdingen, Allart van              Dutch        1621
# 390875                   Allard, Carel              Dutch        1648
# 399753        Dubourg, Louis Fabritius              Dutch        1693
# 400806        Jongkind, Johan Barthold              Dutch        1819
#
#        Artist End Date Artist Gender  \
# 203164      1704                 NaN
# 203388      1627                 NaN
# 203398      1712                 NaN
# 203404      1646                 NaN
# 203423      1669                 NaN
# ...                ...           ...
# 376023      1669                 NaN
# 389006      1675                 NaN
# 390875      1709                 NaN
# 399753      1775                 NaN
# 400806      1891                 NaN
#
#                                    Artist ULAN URL  \
# 203164  http://vocab.getty.edu/page/ulan/500002441
# 203388  http://vocab.getty.edu/page/ulan/500015092
# 203398  http://vocab.getty.edu/page/ulan/500000444
# 203404  http://vocab.getty.edu/page/ulan/500017388
# 203423  http://vocab.getty.edu/page/ulan/500011051
# ...                                            ...
# 376023  http://vocab.getty.edu/page/ulan/500011051
# 389006  http://vocab.getty.edu/page/ulan/500115159
# 390875  http://vocab.getty.edu/page/ulan/500522604
# 399753  http://vocab.getty.edu/page/ulan/500025723
# 400806  http://vocab.getty.edu/page/ulan/500028269
#
#                            Artist Wikidata URL Object Date  Object Begin Date  \
# 203164  https://www.wikidata.org/wiki/Q1133546        1685               1685
# 203388  https://www.wikidata.org/wiki/Q7983530    ca. 1620               1600
# 203398    https://www.wikidata.org/wiki/Q87466   1660–1712               1660
# 203404   https://www.wikidata.org/wiki/Q988828   1600–1650               1600
# 203423     https://www.wikidata.org/wiki/Q5598        1634               1634
# ...                                        ...         ...                ...
# 376023     https://www.wikidata.org/wiki/Q5598        1641               1641
# 389006   https://www.wikidata.org/wiki/Q539036         NaN               1640
# 390875  https://www.wikidata.org/wiki/Q1035877        1673               1673
# 399753  https://www.wikidata.org/wiki/Q6687135    ca. 1730               1725
# 400806   https://www.wikidata.org/wiki/Q704585        1865               1865
#
#         Object End Date                                             Medium  \
# 203164             1685                                            Etching
# 203388             1625      Woodcut; three blocks printed on three sheets
# 203398             1712                                            Etching
# 203404             1650                                            Etching
# 203423             1634                                            Etching
# ...                 ...                                                ...
# 376023             1641  Etching; impression with chimney added to the ...
# 389006             1675                              Etching and engraving
# 390875             1673        Engraving and etching; third or later state
# 399753             1735                              Etching on blue paper
# 400806             1865                               Etching and aquatint
#
#                                                Dimensions  \
# 203164  Sheet: 86 7/8 x 7 3/8 in. (220.7 x 18.8cm)\r\n...
# 203388        Sheet: 18 5/8 x 34 9/16 in. (47.3 x 87.8cm)
# 203398           Sheet: 7 3/16 x 5 1/2 in. (18.21 x 14cm)
# 203404           Sheet: 7 1/2 x 10 3/16 in. (19 x 25.8cm)
# 203423  Sheet: 4 5/16 x 3 9/16 in. (11 x 9.1cm)\r\nPla...
# ...                                                   ...
# 376023  Plate: 5 13/16 × 8 1/8 in. (14.8 × 20.6 cm)\r\...
# 389006  Sheet: 4 1/2 × 4 9/16 in. (11.4 × 11.6 cm)\r\n...
# 390875  Plate: 18 1/2 × 21 5/8 in. (47 × 55 cm)\r\nShe...
# 399753          Sheet: 9 3/4 × 8 1/4 in. (24.7 × 20.9 cm)
# 400806  Plate: 9 3/8 × 12 1/2 in. (23.8 × 31.8 cm)\r\n...
#
#                                               Credit Line Geography Type City  \
# 203164  The Elisha Whittelsey Collection, The Elisha W...            NaN  NaN
# 203388  The Elisha Whittelsey Collection, The Elisha W...            NaN  NaN
# 203398                             Museum accession, 1993            NaN  NaN
# 203404  The Elisha Whittelsey Collection, The Elisha W...            NaN  NaN
# 203423                    Gift of Marietta Morchand, 1994            NaN  NaN
# ...                                                   ...            ...  ...
# 376023                       Gift of Judith A. Webb, 2014            NaN  NaN
# 389006  The Elisha Whittelsey Collection, The Elisha W...            NaN  NaN
# 390875  The Edward W. C. Arnold Collection of New York...            NaN  NaN
# 399753             Purchase, Carolyn H. Specht Gift, 2015            NaN  NaN
# 400806                                  Rogers Fund, 1865            NaN  NaN
#
#        State County Country Region Subregion Locale Locus Excavation River  \
# 203164   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 203388   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 203398   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 203404   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 203423   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# ...      ...    ...     ...    ...       ...    ...   ...        ...   ...
# 376023   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 389006   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 390875   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 399753   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
# 400806   NaN    NaN     NaN    NaN       NaN    NaN   NaN        NaN   NaN
#
#        Classification Rights and Reproduction  \
# 203164         Prints                     NaN
# 203388         Prints                     NaN
# 203398         Prints                     NaN
# 203404         Prints                     NaN
# 203423         Prints                     NaN
# ...               ...                     ...
# 376023         Prints                     NaN
# 389006         Prints                     NaN
# 390875         Prints                     NaN
# 399753         Prints                     NaN
# 400806         Prints                     NaN
#
#                                             Link Resource Object Wikidata URL  \
# 203164  http://www.metmuseum.org/art/collection/search...                 NaN
# 203388  http://www.metmuseum.org/art/collection/search...                 NaN
# 203398  http://www.metmuseum.org/art/collection/search...                 NaN
# 203404  http://www.metmuseum.org/art/collection/search...                 NaN
# 203423  http://www.metmuseum.org/art/collection/search...                 NaN
# ...                                                   ...                 ...
# 376023  http://www.metmuseum.org/art/collection/search...                 NaN
# 389006  http://www.metmuseum.org/art/collection/search...                 NaN
# 390875  http://www.metmuseum.org/art/collection/search...                 NaN
# 399753  http://www.metmuseum.org/art/collection/search...                 NaN
# 400806  http://www.metmuseum.org/art/collection/search...                 NaN
#
#         Metadata Date                                Repository  \
# 203164            NaN  Metropolitan Museum of Art, New York, NY
# 203388            NaN  Metropolitan Museum of Art, New York, NY
# 203398            NaN  Metropolitan Museum of Art, New York, NY
# 203404            NaN  Metropolitan Museum of Art, New York, NY
# 203423            NaN  Metropolitan Museum of Art, New York, NY
# ...               ...                                       ...
# 376023            NaN  Metropolitan Museum of Art, New York, NY
# 389006            NaN  Metropolitan Museum of Art, New York, NY
# 390875            NaN  Metropolitan Museum of Art, New York, NY
# 399753            NaN  Metropolitan Museum of Art, New York, NY
# 400806            NaN  Metropolitan Museum of Art, New York, NY
#
#                                     Tags  \
# 203164                               NaN
# 203388                               NaN
# 203398                               NaN
# 203404                               NaN
# 203423  Reading|Trees|Saint Jerome|Lions
# ...                                  ...
# 376023                         Windmills
# 389006                Houses|Trees|Boats
# 390875                               NaN
# 399753                         Men|Women
# 400806                               NaN
#
#                                              Tags AAT URL  \
# 203164                                                NaN
# 203388                                                NaN
# 203398                                                NaN
# 203404                                                NaN
# 203423  http://vocab.getty.edu/page/aat/300248178|http...
# ...                                                   ...
# 376023          http://vocab.getty.edu/page/aat/300006273
# 389006  http://vocab.getty.edu/page/aat/300005433|http...
# 390875                                                NaN
# 399753  http://vocab.getty.edu/page/aat/300025928|http...
# 400806                                                NaN
#
#                                         Tags Wikidata URL
# 203164                                                NaN
# 203388                                                NaN
# 203398                                                NaN
# 203404                                                NaN
# 203423  https://www.wikidata.org/wiki/Q199657|https://...
# ...                                                   ...
# 376023               https://www.wikidata.org/wiki/Q38720
# 389006  https://www.wikidata.org/wiki/Q3947|https://ww...
# 390875                                                NaN
# 399753  https://www.wikidata.org/wiki/Q8441|https://ww...
# 400806                                                NaN
#
# [1317 rows x 54 columns]

# %% [markdown]
# ##### And there we have it! Now we're off to enjoy looking at some of the prints. . .
