# %% [markdown]
# # Homework 6
# This homework will build off the ideas about error-driven learning and the code you wrote implementing error-driven learning in HW5
#
# In this homework, we will exam how neural networks with **hidden** layers can be used to solve similar classification problems

# %% [markdown]
# **Installing dependencies**

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as R

# supress unnecessary warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %% [markdown]
# ## Question 1
#
# *Creating Training patterns and Teaching Patterns (XOR)*

# %% [markdown]
# Create 200 training patterns for each category, 400 total, 100 from each multivariate normal distribution

# %% [markdown]
# Make sure the matrix of training patterns and the matrix of teacher values are configured properly for Keras
# * You will have to call `gensamples()` 4 times, once for each class

# %% [markdown]
# Here I set the means of the first group to: `(1,1), (-1,-1)`
#
# And the means of the second group to: `(1, -1), (-1, 1)`

# %%
def gensamples(N, mx, my, sx, sy, r):
    M   = np.array([mx, my])
    Cov = np.array([[  sx*sx, r*sx*sy],
                    [r*sx*sy,   sy*sy]])
    return (R.multivariate_normal(M, Cov, size=N, check_valid='warn'))

# %%
# Number of patterns per distribution 
N = 100
s = 3

# First group
mx0 = s;  my0 = s
sx0 = 1.;  sy0 = 1.
r0 = 0.

mx1 = -s; my1 = -s
sx1 = 1.; sy1 = 1.
r1 = 0.

sample0 = gensamples(N, mx0, my0, sx0, sy0, r0)
sample1 = gensamples(N, mx1, my1, sx1, sy1, r1)

# Second group
mx2 = s;  my2 = -s
sx2 = 1.;  sy2 = 1.
r2 = 0.

mx3 = -s;  my3 = s
sx3 = 1.;  sy3 = 1.
r3 = 0.

sample2 = gensamples(N, mx2, my2, sx2, sy2, r2)
sample3 = gensamples(N, mx3, my3, sx3, sy3, r3)

# %%
# Creating the teaching patterns

# (1) Concatenate all the samples
train_pats = np.concatenate((sample0, sample1, sample2, sample3), axis=0)

# (2) Make teaching patterns correspond to training patterns
teach_pats = np.concatenate((np.zeros(2*N), np.ones(2*N)), axis=0)

# (3) Reshaping so teaching patterns are (2N, 1) arrays intead of 2N
print(f"Training pats:\t\t\t{teach_pats.shape}")
teach_pats =  np.reshape(teach_pats, (4*N, 1))
print(f"Training pats reshaped:\t\t{teach_pats.shape}")

print()
print("########### Shapes of in and out #########")
print(train_pats.shape)
print(teach_pats.shape)

test = [0, N, 2*N, 3*N]
for i in test:
    print(f"{train_pats[i]}:\t{teach_pats[i]}")
# Out:
# Training pats:			(400,)
# Training pats reshaped:		(400, 1)
#
# ########### Shapes of in and out #########
# (400, 2)
# (400, 1)
# [2.5167472  4.51008275]:	[0.]
# [-3.16118821 -2.95776593]:	[0.]
# [ 3.94839004 -2.03434768]:	[1.]
# [-1.91338148  2.55094691]:	[1.]

# %%
# plot example
plt.plot(sample0[:,0],sample0[:,1],'b+',sample1[:,0],sample1[:,1],'b+')
plt.plot(sample2[:,0],sample2[:,1],'r+',sample3[:,0],sample3[:,1],'r+')
plt.xlabel('dim1')
plt.ylabel('dim2')
plt.axis('equal')
plt.axis('square')
plt.legend(('class 0', 'class 1'), loc='lower right')
xymin = -6; xymax = 6
plt.ylim((xymin,xymax))
plt.xlim((xymin,xymax))
plt.title('XOR Samples')
plt.show()

# %% [markdown]
# ## Question 2
# *Creating Multi-layer neural network to solve XOR problem*

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

# %%
# Creating feed-forward network
network = models.Sequential()

nin = 2
nhid1 = 3
nhid2 = 3
nout = 1

# First layer
network.add(
    layers.Dense(
        nout,
        activation='tanh',
        input_shape=(nin,)
    )
)

# Second layer
network.add(
    layers.Dense(
        nhid2,
        activation='tanh',
    )
)


# Output layer
network.add(
    layers.Dense(
        nout,
        activation = "tanh"
    )
)

# configure optimizer
sgd = optimizers.SGD(learning_rate=0.01, decay=1e-6, momentum=0.9)

# compile network
network.compile(optimizer=sgd, 
                loss='mean_squared_error', 
                metrics=['accuracy', 'mse'])

# %%
# Shuffling patterns
import numpy.random as rnd
shuffled_idx = rnd.permutation(train_pats.shape[0])
train_pats_shuffled = train_pats[shuffled_idx,:]
teach_pats_shuffled = teach_pats[shuffled_idx,:]

# Should be random
test = [0, N, 2*N, 3*N]
print(np.mean(teach_pats_shuffled[:N]))
for i in test:
    print(f"{train_pats_shuffled[i]}:\t{teach_pats_shuffled[i]}")
# Out:
# 0.52
# [ 3.01234023 -3.45961791]:	[1.]
# [ 3.34536287 -2.07906617]:	[1.]
# [2.07355567 2.65772117]:	[0.]
# [0.63098888 3.15909121]:	[0.]

# %%
epochs = 100
# Training network
history = network.fit(
                      train_pats_shuffled, 
                      teach_pats_shuffled, 
                      verbose=True, 
                      validation_split=.2, 
                      epochs=epochs, 
                      batch_size=10)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3994 - accuracy: 0.4563 - mse: 0.3994 - val_loss: 0.2507 - val_accuracy: 0.4875 - val_mse: 0.2507
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2078 - accuracy: 0.7469 - mse: 0.2078 - val_loss: 0.1694 - val_accuracy: 0.9375 - val_mse: 0.1694
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1526 - accuracy: 0.9312 - mse: 0.1526 - val_loss: 0.1240 - val_accuracy: 0.9750 - val_mse: 0.1240
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.9531 - mse: 0.1106 - val_loss: 0.0905 - val_accuracy: 0.9500 - val_mse: 0.0905
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.9563 - mse: 0.0770 - val_loss: 0.0670 - val_accuracy: 0.9750 - val_mse: 0.0670
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9563 - mse: 0.0663 - val_loss: 0.0541 - val_accuracy: 0.9625 - val_mse: 0.0541
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9719 - mse: 0.0506 - val_loss: 0.0509 - val_accuracy: 0.9875 - val_mse: 0.0509
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9688 - mse: 0.0459 - val_loss: 0.0426 - val_accuracy: 0.9750 - val_mse: 0.0426
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9625 - mse: 0.0400 - val_loss: 0.0358 - val_accuracy: 0.9875 - val_mse: 0.0358
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0366 - accuracy: 0.9750 - mse: 0.0366 - val_loss: 0.0323 - val_accuracy: 0.9750 - val_mse: 0.0323
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9688 - mse: 0.0330 - val_loss: 0.0320 - val_accuracy: 0.9750 - val_mse: 0.0320
# Epoch 12/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.
100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9688 - mse: 0.0228 - val_loss: 0.0206 - val_accuracy: 0.9875 - val_mse: 0.0206
# Epoch 100/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9781 - mse: 0.0227 - val_loss: 0.0250 - val_accuracy: 0.9750 - val_mse: 0.0250

# %% [markdown]
# ### Justification
# * Number of hidden layers (**2 hidden layers**)
#   * 1 hidden layer had poor performance with `softmax`, `relu`, and `tanh` activation functions
#
#
# * Number of nodes per layer (**2 -> 3 -> 3 -> 1**)
#   * 2 or less neurons for seem to lack enough computational complexity to solve XOR in less than 25 epochs
#
# Activation function
# * (`tanh`) worked well for XOR problem when tested on playground, and outperformed `softmax`
#
# Optimizer (and any relevant optimizer settings)
# *  Set learning rate = `.02`, when  `>.05`, accuracy would not be strictly increasing
#
# The number of training epochs
# * Appear to take around 25 - 40 epochs for `accuracy > .9`, but sometimes up to 80
#
# Batch size
# * Smaller batch sizes resulted in accuracy having dips (not strictly increasing)

# %% [markdown]
# ## Question 3 Plotting
# 1. Training accuracy vs epoch
# 2. Loss and Validation loss vs epoch
# 3. Activation function visualization

# %%
accuracy = history.history['accuracy']

plt.plot(accuracy, label="accuracy")
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training Accuracy over Epochs");

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'mse', 'val_loss', 'val_accuracy', 'val_mse'])

# %%
loss, val_loss = history.history['loss'], history.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss over Epochs");

# %%
# Use this function to create a plot for Q4
# xv is array of x-values of test grid (from meshgrid above) --- 
# yv is array of y-values of test grid (from meshgrid above)
# out is the output of the neural network given the test patterns
# sample0, sample1 are the training patterns from earlier

def plottest(xv, yv, out, sample0, sample1):
    # reshape out
    zv = out.reshape(xv.shape)

    # create figure
    fig = plt.figure()
    plt.contourf(xv, yv, zv, levels=xv.shape[0], cmap=plt.cm.gist_yarg)
    plt.plot(sample0[:,0], sample0[:,1], 'b+', 
             sample1[:,0], sample1[:,1], 'r+')    
    
    plt.xlabel('dim1')
    plt.ylabel('dim2')
    plt.axis('equal')
    plt.axis('square')
    xymin = -5; xymax = 7.5
    plt.ylim((xymin,xymax))
    plt.xlim((xymin,xymax))
    plt.show()

xymin = -6
xymax = 6
Npts = 50
xv, yv = np.meshgrid(np.linspace(xymin, xymax, Npts), 
                     np.linspace(xymin, xymax, Npts))
test_pats = np.concatenate((xv.reshape((Npts*Npts,1)), 
                            yv.reshape((Npts*Npts,1))), axis=1)

out = network.predict(test_pats)
class_0 = np.concatenate((sample0, sample1), axis=0)
class_1 = np.concatenate((sample2, sample3), axis=0)
# Out:
# 79/79 [==============================] - 0s 923us/step

# %%
plottest(xv, yv, out, class_0, class_1)

# %% [markdown]
# ## Question 4
# Creating new Classification Problem
#
# Using two classes, create new distributions of points

# %%
# Number of patterns per distribution 
N = 100

# First group
mx0 = 0;  my0 = 0
sx0 = 5;  sy0 = 5
r0 = .95

mx1 = 0; my1 = 0
sx1 = 2.5; sy1 = 2.5
r1 = -.95

sample0 = gensamples(N, mx0, my0, sx0, sy0, r0)
sample1 = gensamples(N, mx1, my1, sx1, sy1, r1)

# Second group
mx2 = -7.5;  my2 = 0
sx2 = 1.5;  sy2 = 1.5
r2 = .1

mx3 = 7.5;  my3 = 0
sx3 = 1.3;  sy3 = 1.3
r3 = 0.2

mx4 = 0;  my4 = 7.5
sx4 = 1.2;  sy4 = 1.6

mx5 = 0;  my5 = -7.5
sx5 = .8;  sy5 = 1.6


sample2 = gensamples(N, mx2, my2, sx2, sy2, r2)
sample3 = gensamples(N, mx3, my3, sx3, sy3, r3)
sample4 =  gensamples(N, mx4, my4, sx4, sy4, r3)
sample5 =  gensamples(N, mx5, my5, sx5, sy5, r3)

# %%
# Creating the teaching patterns

# (1) Concatenate all the samples
train_pats = np.concatenate((sample0, sample1, sample2, sample3, sample4, sample5), axis=0)

# (2) Make teaching patterns correspond to training patterns
teach_pats = np.concatenate((np.zeros(2*N), np.ones(4*N)), axis=0)

# (3) Reshaping so teaching patterns are (2N, 1) arrays intead of 2N
print(f"Training pats:\t\t\t{teach_pats.shape}")
teach_pats =  np.reshape(teach_pats, (6*N, 1))
print(f"Training pats reshaped:\t\t{teach_pats.shape}")

print()
print("########### Shapes of in and out #########")
print(train_pats.shape)
print(teach_pats.shape)
# Out:
# Training pats:			(600,)
# Training pats reshaped:		(600, 1)
#
# ########### Shapes of in and out #########
# (600, 2)
# (600, 1)

# %%
# plot example
plt.plot(sample0[:,0],sample0[:,1],'b+',sample1[:,0],sample1[:,1],'b+')
plt.plot(sample2[:,0],sample2[:,1],'r+',sample3[:,0],sample3[:,1],'r+', sample4[:,0],sample4[:,1],'r+', sample5[:,0],sample5[:,1],'r+')
plt.xlabel('dim1')
plt.ylabel('dim2')
plt.axis('equal')
plt.axis('square')
plt.legend(('class 0', 'class 1'), loc='lower right')
xymin = -10; xymax = 10
plt.ylim((xymin,xymax))
plt.xlim((xymin,xymax))
plt.title('XOR Samples')
plt.show()

# %% [markdown]
# # Question 5
# Create NN to solve Nonlinearly separable classification problem

# %%
# Creating feed-forward network
network = models.Sequential()

nin = 2
nhid1 = 4
nhid2 = 4
nout = 1

# First layer
network.add(
    layers.Dense(
        nout,
        activation='tanh',
        input_shape=(nin,)
    )
)

# Second layer
network.add(
    layers.Dense(
        nhid2,
        activation='tanh',
    )
)

# Output layer
network.add(
    layers.Dense(
        nout,
        activation = "tanh"
    )
)

# configure optimizer
sgd = optimizers.SGD(learning_rate=0.03, decay=1e-6, momentum=0.9)

# compile network
network.compile(optimizer=sgd, 
                loss='mean_squared_error', 
                metrics=['accuracy', 'mse'])

# %%
# Shuffling patterns
import numpy.random as rnd
shuffled_idx = rnd.permutation(train_pats.shape[0])
train_pats_shuffled = train_pats[shuffled_idx,:]
teach_pats_shuffled = teach_pats[shuffled_idx,:]

# Should be random
test = [0, N, 2*N, 3*N]
print(np.mean(teach_pats_shuffled[:N]))
for i in test:
    print(f"{train_pats_shuffled[i]}:\t{teach_pats_shuffled[i]}")
# Out:
# 0.65
# [-0.79644636  7.29112554]:	[1.]
# [-3.0932576  -5.40652017]:	[0.]
# [0.75908712 7.22769327]:	[1.]
# [2.04336084 3.69612476]:	[0.]

# %%
epochs = 200
# Training network
history = network.fit(
                      train_pats_shuffled, 
                      teach_pats_shuffled, 
                      verbose=True, 
                      validation_split=.2, 
                      epochs=epochs, 
                      batch_size=20)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5140 - accuracy: 0.6167 - mse: 0.5140 - val_loss: 0.2453 - val_accuracy: 0.7167 - val_mse: 0.2453
# Epoch 2/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3046 - accuracy: 0.6542 - mse: 0.3046 - val_loss: 0.2429 - val_accuracy: 0.7167 - val_mse: 0.2429
# Epoch 3/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2987 - accuracy: 0.6542 - mse: 0.2987 - val_loss: 0.2375 - val_accuracy: 0.7167 - val_mse: 0.2375
# Epoch 4/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2932 - accuracy: 0.6542 - mse: 0.2932 - val_loss: 0.2313 - val_accuracy: 0.7167 - val_mse: 0.2313
# Epoch 5/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2774 - accuracy: 0.6542 - mse: 0.2774 - val_loss: 0.2152 - val_accuracy: 0.7167 - val_mse: 0.2152
# Epoch 6/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.6542 - mse: 0.2437 - val_loss: 0.2089 - val_accuracy: 0.7167 - val_mse: 0.2089
# Epoch 7/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.6542 - mse: 0.2297 - val_loss: 0.2039 - val_accuracy: 0.7167 - val_mse: 0.2039
# Epoch 8/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.6542 - mse: 0.2347 - val_loss: 0.2047 - val_accuracy: 0.7167 - val_mse: 0.2047
# Epoch 9/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2255 - accuracy: 0.6542 - mse: 0.2255 - val_loss: 0.2054 - val_accuracy: 0.7167 - val_mse: 0.2054
# Epoch 10/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2261 - accuracy: 0.6542 - mse: 0.2261 - val_loss: 0.2086 - val_accuracy: 0.7167 - val_mse: 0.2086
# Epoch 11/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.6542 - mse: 0.2262 - val_loss: 0.1986 - val_accuracy: 0.7167 - val_mse: 0.1986
# Epoch 12/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2235 - accuracy: 0.6542 - mse: 0.2235 - val_loss: 0.1990 - val_accuracy: 0.7167 - val_mse: 0.1990
# Epoch 13/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2190 - accuracy: 0.6542 - mse: 0.2190 - val_loss: 0.1962 - val_accuracy: 0.7167 - val_mse: 0.1962
# Epoch 14/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2175 - accuracy: 0.6750 - mse: 0.2175 - val_loss: 0.1959 - val_accuracy: 0.7417 - val_mse: 0.1959
# Epoch 15/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2082 - accuracy: 0.7042 - mse: 0.2082 - val_loss: 0.1870 - val_accuracy: 0.7917 - val_mse: 0.1870
# Epoch 16/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2026 - accuracy: 0.7167 - mse: 0.2026 - val_loss: 0.1831 - val_accuracy: 0.7333 - val_mse: 0.1831
# Epoch 17/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1933 - accuracy: 0.7375 - mse: 0.1933 - val_loss: 0.1775 - val_accuracy: 0.7667 - val_mse: 0.1775
# Epoch 18/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1661 - accuracy: 0.7896 - mse: 0.1661 - val_loss: 0.1508 - val_accuracy: 0.8167 - val_mse: 0.1508
# Epoch 19/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1451 - accuracy: 0.8313 - mse: 0.1451 - val_loss: 0.1212 - val_accuracy: 0.8583 - val_mse: 0.1212
# Epoch 20/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.
200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.8958 - mse: 0.0914 - val_loss: 0.0972 - val_accuracy: 0.8917 - val_mse: 0.0972
# Epoch 65/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0892 - accuracy: 0.8979 - mse: 0.0892 - val_loss: 0.1059 - val_accuracy: 0.8333 - val_mse: 0.1059
# Epoch 66/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9042 - mse: 0.0833 - val_loss: 0.0941 - val_accuracy: 0.9000 - val_mse: 0.0941
# Epoch 67/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.8542 - mse: 0.1136 - val_loss: 0.1028 - val_accuracy: 0.8750 - val_mse: 0.1028
# Epoch 68/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.8625 - mse: 0.1052 - val_loss: 0.1226 - val_accuracy: 0.8917 - val_mse: 0.1226
# Epoch 69/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.8979 - mse: 0.0906 - val_loss: 0.0907 - val_accuracy: 0.8833 - val_mse: 0.0907
# Epoch 70/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.8771 - mse: 0.0997 - val_loss: 0.1303 - val_accuracy: 0.8417 - val_mse: 0.1303
# Epoch 71/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.8833 - mse: 0.0946 - val_loss: 0.0898 - val_accuracy: 0.8750 - val_mse: 0.0898
# Epoch 72/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.8938 - mse: 0.0898 - val_loss: 0.0954 - val_accuracy: 0.8750 - val_mse: 0.0954
# Epoch 73/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0809 - accuracy: 0.9062 - mse: 0.0809 - val_loss: 0.0890 - val_accuracy: 0.9000 - val_mse: 0.0890
# Epoch 74/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.9062 - mse: 0.0807 - val_loss: 0.0983 - val_accuracy: 0.8917 - val_mse: 0.0983
# Epoch 75/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.8854 - mse: 0.1011 - val_loss: 0.0938 - val_accuracy: 0.9000 - val_mse: 0.0938
# Epoch 76/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.8771 - mse: 0.0964 - val_loss: 0.0968 - val_accuracy: 0.8750 - val_mse: 0.0968
# Epoch 77/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.8771 - mse: 0.1030 - val_loss: 0.1018 - val_accuracy: 0.8833 - val_mse: 0.1018
# Epoch 78/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9042 - mse: 0.0821 - val_loss: 0.0882 - val_accuracy: 0.8833 - val_mse: 0.0882
# Epoch 79/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.8896 - mse: 0.0877 - val_loss: 0.1036 - val_accuracy: 0.8250 - val_mse: 0.1036
# Epoch 80/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.8771 - mse: 0.1000 - val_loss: 0.1221 - val_accuracy: 0.8833 - val_mse: 0.1221
# Epoch 81/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.8896 - mse: 0.0923 - val_loss: 0.0997 - val_accuracy: 0.8333 - val_mse: 0.0997
# Epoch 82/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.8750 - mse: 0.0991 - val_loss: 0.1619 - val_accuracy: 0.8167 - val_mse: 0.1619
# Epoch 83/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 0.8583 - mse: 0.1142 - val_loss: 0.1468 - val_accuracy: 0.8583 - val_mse: 0.1468
# Epoch 84/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.8771 - mse: 0.1034 - val_loss: 0.1028 - val_accuracy: 0.8417 - val_mse: 0.1028
# Epoch 85/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0996 - accuracy: 0.8729 - mse: 0.0996 - val_loss: 0.1054 - val_accuracy: 0.8500 - val_mse: 0.1054
# Epoch 86/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.8958 - mse: 0.0891 - val_loss: 0.0918 - val_accuracy: 0.9083 - val_mse: 0.0918
# Epoch 87/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9000 - mse: 0.0855 - val_loss: 0.0996 - val_accuracy: 0.8833 - val_mse: 0.0996
# Epoch 88/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1097 - accuracy: 0.8542 - mse: 0.1097 - val_loss: 0.1271 - val_accuracy: 0.8917 - val_mse: 0.1271
# Epoch 89/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.8938 - mse: 0.0977 - val_loss: 0.1129 - val_accuracy: 0.8500 - val_mse: 0.1129
# Epoch 90/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0976 - accuracy: 0.8938 - mse: 0.0976 - val_loss: 0.0978 - val_accuracy: 0.8750 - val_mse: 0.0978
# Epoch 91/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9042 - mse: 0.0825 - val_loss: 0.0938 - val_accuracy: 0.8833 - val_mse: 0.0938
# Epoch 92/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.8792 - mse: 0.1027 - val_loss: 0.0960 - val_accuracy: 0.8667 - val_mse: 0.0960
# Epoch 93/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.8875 - mse: 0.0854 - val_loss: 0.0887 - val_accuracy: 0.8750 - val_mse: 0.0887
# Epoch 94/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9021 - mse: 0.0788 - val_loss: 0.0908 - val_accuracy: 0.8917 - val_mse: 0.0908
# Epoch 95/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.8875 - mse: 0.0954 - val_loss: 0.1558 - val_accuracy: 0.7917 - val_mse: 0.1558
# Epoch 96/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1107 - accuracy: 0.8708 - mse: 0.1107 - val_loss: 0.0955 - val_accuracy: 0.8750 - val_mse: 0.0955
# Epoch 97/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9104 - mse: 0.0802 - val_loss: 0.1050 - val_accuracy: 0.8667 - val_mse: 0.1050
# Epoch 98/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9042 - mse: 0.0835 - val_loss: 0.0899 - val_accuracy: 0.9000 - val_mse: 0.0899
# Epoch 99/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0927 - accuracy: 0.8833 - mse: 0.0927 - val_loss: 0.1648 - val_accuracy: 0.7917 - val_mse: 0.1648
# Epoch 100/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.8708 - mse: 0.1119 - val_loss: 0.1044 - val_accuracy: 0.9000 - val_mse: 0.1044
# Epoch 101/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.8667 - mse: 0.1058 - val_loss: 0.1094 - val_accuracy: 0.8500 - val_mse: 0.1094
# Epoch 102/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1159 - accuracy: 0.8562 - mse: 0.1159 - val_loss: 0.1235 - val_accuracy: 0.8333 - val_mse: 0.1235
# Epoch 103/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0948 - accuracy: 0.8854 - mse: 0.0948 - val_loss: 0.1025 - val_accuracy: 0.8917 - val_mse: 0.1025
# Epoch 104/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9021 - mse: 0.0805 - val_loss: 0.1088 - val_accuracy: 0.8833 - val_mse: 0.1088
# Epoch 105/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0956 - accuracy: 0.8813 - mse: 0.0956 - val_loss: 0.0993 - val_accuracy: 0.8750 - val_mse: 0.0993
# Epoch 106/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9021 - mse: 0.0813 - val_loss: 0.0956 - val_accuracy: 0.8750 - val_mse: 0.0956
# Epoch 107/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1077 - accuracy: 0.8729 - mse: 0.1077 - val_loss: 0.1267 - val_accuracy: 0.8417 - val_mse: 0.1267
# Epoch 108/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.8813 - mse: 0.1009 - val_loss: 0.0956 - val_accuracy: 0.8667 - val_mse: 0.0956
# Epoch 109/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.8958 - mse: 0.0863 - val_loss: 0.0892 - val_accuracy: 0.8917 - val_mse: 0.0892
# Epoch 110/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.8750 - mse: 0.1015 - val_loss: 0.0983 - val_accuracy: 0.8417 - val_mse: 0.0983
# Epoch 111/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.8875 - mse: 0.0862 - val_loss: 0.0914 - val_accuracy: 0.8917 - val_mse: 0.0914
# Epoch 112/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 0.8958 - mse: 0.0858 - val_loss: 0.1102 - val_accuracy: 0.8583 - val_mse: 0.1102
# Epoch 113/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.8917 - mse: 0.0903 - val_loss: 0.1149 - val_accuracy: 0.8417 - val_mse: 0.1149
# Epoch 114/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.8813 - mse: 0.0936 - val_loss: 0.0864 - val_accuracy: 0.9000 - val_mse: 0.0864
# Epoch 115/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9042 - mse: 0.0796 - val_loss: 0.0977 - val_accuracy: 0.8667 - val_mse: 0.0977
# Epoch 116/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0896 - accuracy: 0.8854 - mse: 0.0896 - val_loss: 0.0936 - val_accuracy: 0.8917 - val_mse: 0.0936
# Epoch 117/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1273 - accuracy: 0.8438 - mse: 0.1273 - val_loss: 0.1594 - val_accuracy: 0.8000 - val_mse: 0.1594
# Epoch 118/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.8271 - mse: 0.1343 - val_loss: 0.1123 - val_accuracy: 0.8583 - val_mse: 0.1123
# Epoch 119/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.8792 - mse: 0.0953 - val_loss: 0.0943 - val_accuracy: 0.9083 - val_mse: 0.0943
# Epoch 120/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 0.9083 - mse: 0.0764 - val_loss: 0.0939 - val_accuracy: 0.8917 - val_mse: 0.0939
# Epoch 121/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0827 - accuracy: 0.9021 - mse: 0.0827 - val_loss: 0.1160 - val_accuracy: 0.8417 - val_mse: 0.1160
# Epoch 122/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.8646 - mse: 0.0980 - val_loss: 0.0880 - val_accuracy: 0.8917 - val_mse: 0.0880
# Epoch 123/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.9042 - mse: 0.0821 - val_loss: 0.0896 - val_accuracy: 0.9000 - val_mse: 0.0896
# Epoch 124/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9083 - mse: 0.0792 - val_loss: 0.0898 - val_accuracy: 0.8833 - val_mse: 0.0898
# Epoch 125/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.8896 - mse: 0.0934 - val_loss: 0.1737 - val_accuracy: 0.7667 - val_mse: 0.1737
# Epoch 126/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.8917 - mse: 0.0911 - val_loss: 0.0983 - val_accuracy: 0.8667 - val_mse: 0.0983
# Epoch 127/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1045 - accuracy: 0.8687 - mse: 0.1045 - val_loss: 0.1437 - val_accuracy: 0.8167 - val_mse: 0.1437
# Epoch 128/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.8813 - mse: 0.0959 - val_loss: 0.0916 - val_accuracy: 0.8750 - val_mse: 0.0916
# Epoch 129/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.9021 - mse: 0.0831 - val_loss: 0.0964 - val_accuracy: 0.8917 - val_mse: 0.0964
# Epoch 130/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9021 - mse: 0.0838 - val_loss: 0.0949 - val_accuracy: 0.8667 - val_mse: 0.0949
# Epoch 131/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.8938 - mse: 0.0868 - val_loss: 0.0965 - val_accuracy: 0.8917 - val_mse: 0.0965
# Epoch 132/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.8687 - mse: 0.1052 - val_loss: 0.1159 - val_accuracy: 0.8583 - val_mse: 0.1159
# Epoch 133/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.8854 - mse: 0.0964 - val_loss: 0.0986 - val_accuracy: 0.8750 - val_mse: 0.0986
# Epoch 134/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9000 - mse: 0.0847 - val_loss: 0.0864 - val_accuracy: 0.9083 - val_mse: 0.0864
# Epoch 135/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.8896 - mse: 0.0888 - val_loss: 0.1064 - val_accuracy: 0.8750 - val_mse: 0.1064
# Epoch 136/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.8396 - mse: 0.1258 - val_loss: 0.0946 - val_accuracy: 0.8750 - val_mse: 0.0946
# Epoch 137/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0882 - accuracy: 0.8979 - mse: 0.0882 - val_loss: 0.1080 - val_accuracy: 0.8500 - val_mse: 0.1080
# Epoch 138/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0851 - accuracy: 0.8938 - mse: 0.0851 - val_loss: 0.0901 - val_accuracy: 0.9000 - val_mse: 0.0901
# Epoch 139/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.8854 - mse: 0.0905 - val_loss: 0.0883 - val_accuracy: 0.8917 - val_mse: 0.0883
# Epoch 140/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.8792 - mse: 0.0975 - val_loss: 0.0903 - val_accuracy: 0.8917 - val_mse: 0.0903
# Epoch 141/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0897 - accuracy: 0.8896 - mse: 0.0897 - val_loss: 0.0996 - val_accuracy: 0.9000 - val_mse: 0.0996
# Epoch 142/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9021 - mse: 0.0846 - val_loss: 0.0958 - val_accuracy: 0.8500 - val_mse: 0.0958
# Epoch 143/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9021 - mse: 0.0826 - val_loss: 0.1027 - val_accuracy: 0.8917 - val_mse: 0.1027
# Epoch 144/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.8958 - mse: 0.0841 - val_loss: 0.0872 - val_accuracy: 0.9083 - val_mse: 0.0872
# Epoch 145/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9104 - mse: 0.0790 - val_loss: 0.0936 - val_accuracy: 0.9000 - val_mse: 0.0936
# Epoch 146/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.8792 - mse: 0.0946 - val_loss: 0.0933 - val_accuracy: 0.8917 - val_mse: 0.0933
# Epoch 147/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1029 - accuracy: 0.8750 - mse: 0.1029 - val_loss: 0.1213 - val_accuracy: 0.8833 - val_mse: 0.1213
# Epoch 148/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.8979 - mse: 0.0831 - val_loss: 0.0937 - val_accuracy: 0.8917 - val_mse: 0.0937
# Epoch 149/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9042 - mse: 0.0787 - val_loss: 0.0893 - val_accuracy: 0.8917 - val_mse: 0.0893
# Epoch 150/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.8813 - mse: 0.0905 - val_loss: 0.0887 - val_accuracy: 0.8750 - val_mse: 0.0887
# Epoch 151/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.8667 - mse: 0.0973 - val_loss: 0.1092 - val_accuracy: 0.8417 - val_mse: 0.1092
# Epoch 152/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 0.9021 - mse: 0.0876 - val_loss: 0.0899 - val_accuracy: 0.8917 - val_mse: 0.0899
# Epoch 153/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9021 - mse: 0.0826 - val_loss: 0.0883 - val_accuracy: 0.8917 - val_mse: 0.0883
# Epoch 154/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0845 - accuracy: 0.8938 - mse: 0.0845 - val_loss: 0.0908 - val_accuracy: 0.8750 - val_mse: 0.0908
# Epoch 155/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 0.8625 - mse: 0.1084 - val_loss: 0.1151 - val_accuracy: 0.8667 - val_mse: 0.1151
# Epoch 156/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.8979 - mse: 0.0840 - val_loss: 0.0890 - val_accuracy: 0.8917 - val_mse: 0.0890
# Epoch 157/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0832 - accuracy: 0.8958 - mse: 0.0832 - val_loss: 0.1082 - val_accuracy: 0.8500 - val_mse: 0.1082
# Epoch 158/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0993 - accuracy: 0.8833 - mse: 0.0993 - val_loss: 0.0887 - val_accuracy: 0.8917 - val_mse: 0.0887
# Epoch 159/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9146 - mse: 0.0782 - val_loss: 0.0849 - val_accuracy: 0.9083 - val_mse: 0.0849
# Epoch 160/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0842 - accuracy: 0.8958 - mse: 0.0842 - val_loss: 0.1096 - val_accuracy: 0.8583 - val_mse: 0.1096
# Epoch 161/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0917 - accuracy: 0.8896 - mse: 0.0917 - val_loss: 0.0885 - val_accuracy: 0.8750 - val_mse: 0.0885
# Epoch 162/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.8938 - mse: 0.0794 - val_loss: 0.1011 - val_accuracy: 0.8833 - val_mse: 0.1011
# Epoch 163/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0889 - accuracy: 0.8979 - mse: 0.0889 - val_loss: 0.0856 - val_accuracy: 0.9000 - val_mse: 0.0856
# Epoch 164/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.8562 - mse: 0.1145 - val_loss: 0.1168 - val_accuracy: 0.8333 - val_mse: 0.1168
# Epoch 165/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0917 - accuracy: 0.8813 - mse: 0.0917 - val_loss: 0.0916 - val_accuracy: 0.8917 - val_mse: 0.0916
# Epoch 166/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.8917 - mse: 0.0850 - val_loss: 0.1045 - val_accuracy: 0.8583 - val_mse: 0.1045
# Epoch 167/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0937 - accuracy: 0.8917 - mse: 0.0937 - val_loss: 0.1127 - val_accuracy: 0.8750 - val_mse: 0.1127
# Epoch 168/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9042 - mse: 0.0830 - val_loss: 0.0890 - val_accuracy: 0.8667 - val_mse: 0.0890
# Epoch 169/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.8854 - mse: 0.0899 - val_loss: 0.0995 - val_accuracy: 0.8917 - val_mse: 0.0995
# Epoch 170/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.8813 - mse: 0.0926 - val_loss: 0.0989 - val_accuracy: 0.8917 - val_mse: 0.0989
# Epoch 171/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.8917 - mse: 0.0903 - val_loss: 0.0963 - val_accuracy: 0.8500 - val_mse: 0.0963
# Epoch 172/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.9083 - mse: 0.0807 - val_loss: 0.0964 - val_accuracy: 0.8750 - val_mse: 0.0964
# Epoch 173/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9083 - mse: 0.0816 - val_loss: 0.0896 - val_accuracy: 0.8917 - val_mse: 0.0896
# Epoch 174/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9104 - mse: 0.0763 - val_loss: 0.1145 - val_accuracy: 0.8667 - val_mse: 0.1145
# Epoch 175/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.8604 - mse: 0.1098 - val_loss: 0.0878 - val_accuracy: 0.8917 - val_mse: 0.0878
# Epoch 176/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9062 - mse: 0.0784 - val_loss: 0.0914 - val_accuracy: 0.9000 - val_mse: 0.0914
# Epoch 177/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9042 - mse: 0.0784 - val_loss: 0.0847 - val_accuracy: 0.8917 - val_mse: 0.0847
# Epoch 178/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9042 - mse: 0.0803 - val_loss: 0.0896 - val_accuracy: 0.8917 - val_mse: 0.0896
# Epoch 179/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9000 - mse: 0.0843 - val_loss: 0.0891 - val_accuracy: 0.8833 - val_mse: 0.0891
# Epoch 180/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0865 - accuracy: 0.9021 - mse: 0.0865 - val_loss: 0.1011 - val_accuracy: 0.8667 - val_mse: 0.1011
# Epoch 181/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.8896 - mse: 0.0862 - val_loss: 0.1173 - val_accuracy: 0.8833 - val_mse: 0.1173
# Epoch 182/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.8917 - mse: 0.0868 - val_loss: 0.0871 - val_accuracy: 0.8833 - val_mse: 0.0871
# Epoch 183/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0789 - accuracy: 0.9000 - mse: 0.0789 - val_loss: 0.0886 - val_accuracy: 0.9000 - val_mse: 0.0886
# Epoch 184/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9042 - mse: 0.0784 - val_loss: 0.0911 - val_accuracy: 0.8917 - val_mse: 0.0911
# Epoch 185/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.8854 - mse: 0.0907 - val_loss: 0.0986 - val_accuracy: 0.8583 - val_mse: 0.0986
# Epoch 186/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1244 - accuracy: 0.8375 - mse: 0.1244 - val_loss: 0.1252 - val_accuracy: 0.8167 - val_mse: 0.1252
# Epoch 187/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0929 - accuracy: 0.8938 - mse: 0.0929 - val_loss: 0.0904 - val_accuracy: 0.8917 - val_mse: 0.0904
# Epoch 188/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9104 - mse: 0.0801 - val_loss: 0.0848 - val_accuracy: 0.8917 - val_mse: 0.0848
# Epoch 189/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.9104 - mse: 0.0751 - val_loss: 0.0915 - val_accuracy: 0.8833 - val_mse: 0.0915
# Epoch 190/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9000 - mse: 0.0824 - val_loss: 0.0908 - val_accuracy: 0.8917 - val_mse: 0.0908
# Epoch 191/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.8979 - mse: 0.0826 - val_loss: 0.0997 - val_accuracy: 0.8500 - val_mse: 0.0997
# Epoch 192/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9042 - mse: 0.0838 - val_loss: 0.0857 - val_accuracy: 0.9083 - val_mse: 0.0857
# Epoch 193/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.8875 - mse: 0.0869 - val_loss: 0.0968 - val_accuracy: 0.8833 - val_mse: 0.0968
# Epoch 194/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.8729 - mse: 0.1027 - val_loss: 0.1138 - val_accuracy: 0.8917 - val_mse: 0.1138
# Epoch 195/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9083 - mse: 0.0838 - val_loss: 0.0949 - val_accuracy: 0.8667 - val_mse: 0.0949
# Epoch 196/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0861 - accuracy: 0.8938 - mse: 0.0861 - val_loss: 0.0919 - val_accuracy: 0.9000 - val_mse: 0.0919
# Epoch 197/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.8917 - mse: 0.0891 - val_loss: 0.0864 - val_accuracy: 0.8833 - val_mse: 0.0864
# Epoch 198/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9104 - mse: 0.0753 - val_loss: 0.0953 - val_accuracy: 0.8917 - val_mse: 0.0953
# Epoch 199/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0902 - accuracy: 0.8896 - mse: 0.0902 - val_loss: 0.1036 - val_accuracy: 0.8500 - val_mse: 0.1036
# Epoch 200/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.9146 - mse: 0.0788 - val_loss: 0.0874 - val_accuracy: 0.9083 - val_mse: 0.0874

# %% [markdown]
# ### Justification
# * Number of hidden layers (**2 hidden layers**)
#   * 1 hidden layer had poor performance with `tanh` activation functions
#
#
# * Number of nodes per layer (**2 -> 4 -> 4 -> 1**)
#   * using 2-3 nodes on either hidden layer resulted in less reliable classification
#
# Activation function
# * (`tanh`) worked well for XOR problem when tested on playground, and outperformed `softmax`
#
# Optimizer (and any relevant optimizer settings)
# *  Set learning rate = `.02`, when  `>.05`, accuracy would not be strictly increasing and when smaller takes longer to train
#
# The number of training epochs
# * Appear to take around 50+ epochs for `accuracy > .85`
#
# Batch size
# * Smaller batch sizes resulted in accuracy having dips (not strictly increasing)

# %% [markdown]
# # Question 6

# %%
accuracy = history.history['accuracy']

plt.plot(accuracy, label="accuracy")
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training Accuracy over Epochs");

# %%
loss, val_loss = history.history['loss'], history.history["val_loss"]

plt.plot(loss, label="loss")
plt.plot(val_loss, label="val_loss")
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss over Epochs");

# %%
def plottest(xv, yv, out, sample0, sample1):
    # reshape out
    zv = out.reshape(xv.shape)

    # create figure
    fig = plt.figure()
    plt.contourf(xv, yv, zv, levels=xv.shape[0], cmap=plt.cm.gist_yarg)
    plt.plot(sample0[:,0], sample0[:,1], 'b+', 
             sample1[:,0], sample1[:,1], 'r+')    
    
    plt.xlabel('dim1')
    plt.ylabel('dim2')
    plt.axis('equal')
    plt.axis('square')
    xymin = -10; xymax = 10
    plt.ylim((xymin,xymax))
    plt.xlim((xymin,xymax))
    plt.show()

xymin = -10
xymax = 10
Npts = 50
xv, yv = np.meshgrid(np.linspace(xymin, xymax, Npts), 
                     np.linspace(xymin, xymax, Npts))
test_pats = np.concatenate((xv.reshape((Npts*Npts,1)), 
                            yv.reshape((Npts*Npts,1))), axis=1)

out = network.predict(test_pats)
class_0 = np.concatenate((sample0, sample1), axis=0)
class_1 = np.concatenate((sample2, sample3, sample4, sample5), axis=0)
# Out:
# 79/79 [==============================] - 0s 958us/step

# %%
plottest(xv, yv, out, class_0, class_1)
